# %% [markdown]
# **This project is due Wednesday, October 22, 2025 at 11:59 pm. Please plan ahead and submit your work on time.**

# %% [markdown]
# <center><h1>Grad Project #1</h1></center>

# %% [markdown]
# In this first project for 16.413 / 6.4132, we are going to look at the search and rescue domain using symbolic representations. We are going to look at both planning using PDDL, and also inference using PDDL. This project isn't going to focus on implementing specific algorithms however -- we're going to use two libraries: `pyperplan` and `sympy`. (You'll remember them from problem sets 3 and 4).
#
# The project is structured as follows:
#
# 0. [Credit for Contributors (required)](#contributors)
# 1. [Planning in Search and Rescue (15 points)](#planning_in_sar)
#     1. [Search and Rescue Warmup 1 (5 points)](#warmup_1)
#     2. [Search and Rescue Warmup 2 (5 points)](#warmup_2)
#     3. [Search and Rescue PDDL Planner (5 points)](#sar_pddl)
# 2. [Inference from Observations (20 points)](#inference)
#     1. [Inferring unknown values (10 points)](#infer_unknowns)
#     2. [Belief update (10 points)](#belief_update)
# 3. [Putting It Together (35 points)](#integrated)
#     1. [Safe but not so smart (7 points)](#safe_no_smart)
#     2. [Safe and smart (7 points)](#safe_smart)
#     3. [Reckless (7 points)](#reckless)
#     4. [Safe and smart if possible, else reckless (7 points)](#safe_smart_reckless)
#     5. [Looks before it leaps (7 points)](#look_before)
# 4. [Analysis (30 points)](#analysis)
# 5. [Feedback](#feedback)

# %% [markdown]
# ## <a id="contributors"></a>0. Credit for Contributors
#
# List the various students, lecture notes, or online resouces that helped you complete this project:
#
# Ex: I worked with Bob on the inference.
#
# <div class="alert alert-info">
# Write your answer in the cell below this one.
# </div>

# %% [markdown]
# Looked at lecture notes and asked chatGPT for help with understanding concepts.

# %% [markdown]
# ## Imports and Utilities

# %%
import time
import numpy as np
from sympy import Symbol, And, Or, satisfiable
from utils import *

# %load_ext autoreload
# %autoreload 2
from principles_of_autonomy.grader import Grader
from principles_of_autonomy.notebook_tests.proj_1 import TestProj1

# %% [markdown]
# ## <a id="planning_in_sar"></a> 1. Planning in Search and Rescue (15 points)
#
# Let's say that we have a "search and rescue" robot who is charged with navigating a sometimes dangerous grid to find and help people in need. We will restrict ourselves to a deterministic problem domain; we will however look at both fully observed and partially observed cases.
#
# Let us first focus on a single planning problem in the search-and-rescue domain, illustrated below:
#
# ![search and rescue problem](sar_problem.png)
#
# This problem features four "people" (bears) with names p1, p2, p3, and p4. A robot, initialized in the top left corner, should navigate to each person, pick them up one by one, and deliver them to the hospital (bottom right).
#
# * We always know the locations of the people, the robot, and the hospital.
# * Some locations may have walls in them.  **You know about all the walls in advance, as well.**
# * There is also fire!  And smoke!  But, initially, you may not know which locations have fire and/or smoke. Therefore, you need to move around in the domain, make observations, update your belief (e.g., infer whether there may be fire or smoke in the cells you haven't observed yet), make plans, and rescue bears.
# * Whenever the robot enters a grid cell, it observes the true environment state of all the neighboring cells.  Each environment cell contains exactly one of:  wall ('W'), fire ('F'), smoke ('S') or nothing (clear, 'C').
# * The robot may safely enter any cell that is clear ('C') or contains smoke ('S').
#
# We will first consider planning to navigate to, pick up, and drop off people at a hospital, and we are going to ask you to put this all together into a planning and execution system!
#
# Take a look at the code.  `State` is a class with the following attributes:
#
# * "state_map": a 2D numpy array of characters 'W', 'F', 'S', 'C'.
# * "robot": A (row, col) representing the robot's loc.
# * "hospital": A (row, col) representing the hospital's loc.
# * "carrying": The str name of a person being carried, or None, if no person is being carried.
# * "people": A dict mapping str people names to (row, col) locs. If a person is being carried, they do not appear in this dict.
#
# States have a couple of useful methods: `render` returns a string representation of the state (which can be printed) and `copy` does what you would expect. `get_safe_grid` returns a boolean numpy array where True represents a safe space (not fire or wall).
#
# Actions are strings:
# * "up" / "down" / "left" / "right" : Moves the robot. The robot cannot move into obstacles or off the map.
# * "pickup-{person}": If the robot is at the person, and if the robot is not already carrying someone, pick up this person.
# * "dropoff": If the robot is carrying a person, they are dropped off at the robot's current location.  *Allow for there being multiple dropoff locations, even though we will only dropoff at hospitals in this example.*
#
# Please now take a moment to read the docstring for `SearchAndRescueProblem` to make sure that you understand the state and action spaces.
#
# Finally, we're going to use a Python PDDL planner called `pyperplan` [(more info here)](https://github.com/aibasel/pyperplan) to find our plans.
#
# Let's familiarize ourselve with State and SearchAndRescueProblem.

# %% [markdown]
# ### <a id="warmup_1"></a> 1A. Search and Rescue Warmup 1 (5 points)

# %% [markdown]
# Let's make sure we can access fields of the SearchAndRescue State. Please write a function to check if a row and column have an obstacle in a SearchAndRescue State.
#
# For reference, our solution is **1** line(s) of code.

# %%
def sar_warmup1(sar_state: State, row: int, col: int) -> bool:
    """Check if a row and col have an obstacle in a SearchAndRescueProblem
    state.

    Args:
      sar_state: A SearchAndRescue State.
      row: An int.
      col: An int.

    Returns:
      has_obstacle: True if (row, col) has an obstacle(wall) in sar_state.
    """
    return sar_state.state_map[row, col] == 'W'

# %%
# Test 1
Grader.run_single_test_inline(TestProj1, "test_01_warmup_1", locals())
# Out:
# <div class="alert alert-success">
#         <strong>Test passed!!</strong>
#         </div>
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.002s
#
# OK

# %% [markdown]
# ### <a id="warmup_2"></a> 1B. Search and Rescue Warmup 2 (5 points)

# %% [markdown]
# Let's make sure we know how to encode a plan. Please write a function that returns a hard-coded list of actions that will deliver person 'p1' (in the image above) to the hospital location. (You'll need to work out the plan for yourself -- don't use `pyperplan` yet!)
#
# For reference, our solution is **1** line(s) of code.

# %%
def sar_warmup2() -> list[str]:
    """Hand-code a list of actions that will deliver person 'p1' to the
    hospital location.

    Returns:
      actions: A list of str actions that will take person p1 to the hospital loccation.
    """
    return ["down", "down", "down", "down", "pickup-p1", "up", "up", "right", "right", "right", "right", "right", "right", "down", "down", "down", "down", "dropoff"]

# %%
# Test 2
Grader.run_single_test_inline(TestProj1, "test_02_warmup_2", locals())
# Out:
#             <div style="margin-bottom:16px; border:1px solid #ddd; padding:8px;">
#                 <input type="range" id="df44137a_8095_459f_b5a3_99d596bcdd5e_slider" min="0" max="18" value="0" style="width:100%">
#                 <div id="df44137a_8095_459f_b5a3_99d596bcdd5e_label" style="font-family: sans-serif; margin-top:4px; font-size: 14px;">
#                     Render 1 of 19
#                 </div>
#                 <pre id="df44137a_8095_459f_b5a3_99d596bcdd5e_container" style="font-family: monospace; white-space: pre; border:1px solid #ccc; padding:10px; margin-top:8px;"></pre>
#             </div>
#             <script>
#                 const states_df44137a_8095_459f_b5a3_99d596bcdd5e = [`execute_plan: down
# ##################
# ##Ro          p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`execute_plan: down
# ##################
# ##            p3##
# ##Ro####    ######
# ##              ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`execute_plan: down
# ##################
# ##            p3##
# ##  ####    ######
# ##Ro            ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`execute_plan: down
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##Ro  ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`execute_plan: pickup-p1
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##R1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`execute_plan: up
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##Ro  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: p1
# `,`execute_plan: up
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##Ro  ##p4      ##
# ##    ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: p1
# `,`execute_plan: right
# ##################
# ##            p3##
# ##  ####    ######
# ##Ro            ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: p1
# `,`execute_plan: right
# ##################
# ##            p3##
# ##  ####    ######
# ##  Ro          ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: p1
# `,`execute_plan: right
# ##################
# ##            p3##
# ##  ####    ######
# ##    Ro        ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: p1
# `,`execute_plan: right
# ##################
# ##            p3##
# ##  ####    ######
# ##      Ro      ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: p1
# `,`execute_plan: right
# ##################
# ##            p3##
# ##  ####    ######
# ##        Ro    ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: p1
# `,`execute_plan: right
# ##################
# ##            p3##
# ##  ####    ######
# ##          Ro  ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: p1
# `,`execute_plan: down
# ##################
# ##            p3##
# ##  ####    ######
# ##            Ro##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: p1
# `,`execute_plan: down
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4    Ro##
# ##    ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: p1
# `,`execute_plan: down
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##  Ro##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: p1
# `,`execute_plan: down
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##          ##Ro##
# ##p2##    ##  Ho##
# ##################
# Carrying: p1
# `,`execute_plan: dropoff
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ro##
# ##################
# Carrying: p1
# `,`execute_plan: Final state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ro##
# ##################
# Carrying: None
# `];
#                 const slider_df44137a_8095_459f_b5a3_99d596bcdd5e = document.getElementById("df44137a_8095_459f_b5a3_99d596bcdd5e_slider");
#                 const container_df44137a_8095_459f_b5a3_99d596bcdd5e = document.getElementById("df44137a_8095_459f_b5a3_99d596bcdd5e_container");
#                 const label_df44137a_8095_459f_b5a3_99d596bcdd5e = document.getElementById("df44137a_8095_459f_b5a3_99d596bcdd5e_label");
#
#                 function update_df44137a_8095_459f_b5a3_99d596bcdd5e() {
#                     const i = parseInt(slider_df44137a_8095_459f_b5a3_99d596bcdd5e.value, 10);
#                     container_df44137a_8095_459f_b5a3_99d596bcdd5e.textContent = states_df44137a_8095_459f_b5a3_99d596bcdd5e[i];
#                     label_df44137a_8095_459f_b5a3_99d596bcdd5e.textContent = "Render " + (i+1) + " of 19";
#                 }
#
#                 slider_df44137a_8095_459f_b5a3_99d596bcdd5e.addEventListener("input", update_df44137a_8095_459f_b5a3_99d596bcdd5e);
#                 update_df44137a_8095_459f_b5a3_99d596bcdd5e();  // initialize
#             </script>
# <div class="alert alert-success">
#         <strong>Test passed!!</strong>
#         </div>
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.010s
#
# OK

# %% [markdown]
# ### <a id="sar_pddl"></a> 1C. Search and Rescue PDDL Planner (5 points)

# %% [markdown]
# Now that you're warmed up, let's try making a planner to solve a SearchAndRescueProblem!
#
# The core function in this planner class is 'get_plan'. This function needs to do the following:
# 1. Create PDDL domain and problem strings for search and rescue. The operators should work for any grid size, obstacles, people locations, and hospital location.
# 2. Invoke `run_planning` using the given `search_algo` search algorithm with the `heuristic` heuristic.
# 3. Convert the output of `run_planning` (pyperplan Operators) into actions that can be executed, via `execute_plan`.
#
# We have given you most of the structure of the needed functions, but you will need to look (carefully!) through the provided python to find the `TODO` sections that you need to complete.
#
# For reference, 'get_plan' takes ~1-2 seconds to run with our implementation if using 'gbf' search and 'hff' heuristic. To get credit on Gradescope, make sure that your function finishes in <10 seconds.
#
# **Notes**:
# * In this problem, you will need to construct somewhat complicated strings.  We *strongly* encourage you to read about [Python-3 f-strings](https://www.digitalocean.com/community/tutorials/how-to-use-f-strings-to-create-strings-in-python-3) which make this process much easier than the alternatives.
# * You may find `state.render()` useful for debugging.
# * We also highly recommend printing out the domain and problem after they have been created, and copying them into [editor.planning.domains](http://editor.planning.domains) to check whether it's possible to find a plan. This editor can be helpful for syntax checking.
# * We also recommend writing careful test cases for yourself --- it's really easy to forget preconditions or effects. When we were debugging this, we forgot to make sure that the robot was at the location of the person that it picked up, so the plans were (confusingly) super short!
# * The image above with the robot and the bears is a faithful depiction of the initial state. For example, the initial locations of the people are: `"p1": (4, 0), "p2": (6, 0), "p3": (0, 6), "p4": (3, 3)`.
# * One part of this problem that may be initially counterintuitive is the way that we'll represent locations in PDDL. In the problem, a location is a tuple of integers. PDDL does not support such representations -- everything needs to be just an object with a string name.
# So to represent a location like (3, 5), we will make a string `"l3-5"` (where the first character there is a lowercase L), and we'll create an object with that name, of type "location". We will also need a way to encode the fact that the robot can only move between adjacent locations in the grid.
# In Python, we can compare the numeric values of locations like (3, 5) and (3, 6) to see if they are neighbors. But in PDDL, all we have are the objects with string names, and we need to encode everything in terms of predicates. So, we will create a predicate `(conn ?v0 - location ?v1 - location ?v2 - direction)`, which says that location `?v0` is connected to location `?v1` in direction `?v2`. For example, `(conn l3-5 l3-6 right)` might appear in the initial state. We can then use these `conn` predicates in the preconditions of a `move` operator to encode the fact that the robot can only move between adjacent locations.
# * We do not recommend modelling the hospital explicitly with special objects / types / predicates. Instead, the goal should be to deliver all people to the hospital, that is, `l6-6`.
# In words, the goal should be `"person1 is at l6-6 and person2 is at l6-6 and person3 is at l6-6 and person4 is at l6-6"`.

# %%
class SearchAndRescuePlanner:
    """A planner for a search and rescue problem.

    The core function in this class is 'get_plan'
    This function does the following:
        1. Create PDDL domain and problem strings for search and rescue. The operators should work for any grid size, obstacles, people locations, and hospital location.
        2. Invoke `run_planning` using the given `search_algo` search algorithm with the `heuristic` heuristic.
        3. Convert the output of run_planning (pyperplan Operators) into actions
           that can be given to the SearchAndRescueProblem.

    Example Usage:
        problem = SearchAndRescueProblem()
        state = State()

        planner = SearchAndRescuePlanner(search_algo='astar', heuristic='lmcut')
        plan, plan_time = planner.get_plan(state)
        state = execute_plan(problem, plan, state)

    'get_plan' Returns:
        plan: A list of actions; each action is a str, see SearchAndRescueProblem.
        plan_time: Total planning time(sec) used for plan searching.

    For reference, 'get_plan' takes ~1-2 seconds to run with our implementation if using 'gbf' search and 'lmcut' heuristic.
    """

    def __init__(self, search_algo='astar', heuristic='lmcut'):
        self.search_algo = search_algo
        self.heuristic = heuristic

    def generate_domain_pddl(self,
                             domain_name,
                             added_operators='',
                             added_predicates=''):
        predicates_str = """(conn ?v0 - location ?v1 - location ?v2 - direction)
        (is-clear ?v0 - location)
        (robot-at ?v0 - location)
        (person-at ?v0 - person ?v1 - location)
        (carrying ?v0 - person)
        (handsfree)
        """
        
        operators_str = """(:action move-robot
    :parameters (?from - location ?to - location ?dir - direction)
    :precondition (and
      (conn ?from ?to ?dir)
      (robot-at ?from)
      (is-clear ?to)
    )
    :effect (and
      (not (robot-at ?from))
      (robot-at ?to)
    )
  )
  (:action pickup-person
    :parameters (?person - person ?loc - location)
    :precondition (and
      (robot-at ?loc)
      (person-at ?person ?loc)
      (handsfree)
    )
    :effect (and
      (not (person-at ?person ?loc))
      (not (handsfree))
      (carrying ?person)
    )
  )
  (:action dropoff-person
    :parameters (?person - person ?loc - location)
    :precondition (and
      (robot-at ?loc)
      (carrying ?person)
    )
    :effect (and
      (not (carrying ?person))
      (handsfree)
      (person-at ?person ?loc)
    )
  )"""

        domain_pddl = f"""(define (domain {domain_name})
    (:requirements :typing)
    (:types person location direction)
    (:constants
      down - direction
      left - direction
      right - direction
      up - direction
    )
    (:predicates
      {predicates_str}
      {added_predicates}
    )
    {operators_str}
    {added_operators}
)"""
        return domain_pddl

    def get_plan(self, state):
        search_algo, heuristic = self.search_algo, self.heuristic
        domain_name, added_predicate, added_operator = self.update_pddl_domain()
        domain_pddl = self.generate_domain_pddl(
            domain_name,
            added_operators=added_operator,
            added_predicates=added_predicate)
        # Create objects str
        obj_str = self.get_obj_strs(state)

        # Create init str
        init_str = self.get_init_strs(state)

        # Create goal str
        goal_str = self.get_goal_strs(state)

        problem_pddl = f"""(define (problem searchandrescue) (:domain {domain_name})
      (:objects
      {obj_str}
      )
      (:init
      {init_str}
      )
      (:goal (and {goal_str}))
    )"""

        start_time = time.time()
        plan = run_planning(domain_pddl, problem_pddl, search_algo, heuristic)
        time_elapsed = time.time() - start_time
        if plan is None:
            print("Failed to find a plan.")
            return None, time_elapsed

        # Convert operators to actions
        actions = self.parse_plan(plan)
        return actions, time_elapsed

    def get_obj_strs(self, state):
        height, width = state.state_map.shape
        objects_strs = [f"{person} - person" for person in state.people]
        for r in range(height):
            for c in range(width):
                objects_strs.append(f"l{r}-{c} - location")
    
        if state.carrying is not None:
            objects_strs.append(f"{state.carrying} - person")
        objects_str = " ".join(objects_strs)
        return objects_str

    def get_init_strs(self, state):
        height, width = state.state_map.shape
        robot_r, robot_c = state.robot
        init_strs = [f"(robot-at l{robot_r}-{robot_c})"]
        for person, (r, c) in state.people.items():
            init_strs.append(f"(person-at {person} l{r}-{c})")
        if state.carrying is not None:
            init_strs.append(f"(carrying {state.carrying})")
        else:
            init_strs.append("(handsfree)")
            
        deltas = {
            "up": (-1, 0),
            "down": (1, 0),
            "left": (0, -1),
            "right": (0, 1),
        }
        
        safe_grid = state.get_safe_grid()
        for r in range(height):
            for c in range(width):
                # Here we're going to add one (conn ...) atom for every pair
                # of adjacent locations.
                for direction, (dr, dc) in deltas.items():
                    if not (0 <= r + dr < height and 0 <= c + dc < width):
                        continue
                    # For example, if r == 0, c == 0, dr == 0, dc == 1, then
                    # this line adds the atom (conn l0-0 l0-1 right).
                    init_strs.append(
                        f"(conn l{r}-{c} l{r + dr}-{c + dc} {direction})")
                if safe_grid[r, c]:
                    init_strs.append(f"(is-clear l{r}-{c})")

        init_str = " ".join(init_strs)
        return init_str

    def get_goal_strs(self, state):
        goal_strs = []
        hospital_r, hospital_c = state.hospital
        for person in state.people:
            goal_strs.append(f"(person-at {person} l{hospital_r}-{hospital_c})")
        

        if state.carrying is not None:
            goal_strs.append(f"(person-at {state.carrying} l{hospital_r}-{hospital_c})")
        goal_str = " ".join(goal_strs)
        return goal_str

    def update_pddl_domain(self):
        domain_name = 'searchandrescue'
        added_predicate = ''
        added_operator = ''
        return domain_name, added_predicate, added_operator

    def parse_plan(self, plan):
        actions = []
        for op in plan:
            if "move-robot" in op.name:
                _, direction = op.name[:-1].rsplit(" ", 1)
                action = direction
            elif "pickup-person" in op.name:
                _, person, _ = op.name.split(" ")
                action = f"pickup-{person}"
            else:
                assert "dropoff-person" in op.name
                action = "dropoff"
            actions.append(action)
        return actions

# %% [markdown]
# Visualize to make sure your planner does what you expect

# %%
sar_pddl_problem = SearchAndRescueProblem()
sar_pddl_planner = SearchAndRescuePlanner(search_algo="gbf", heuristic="hff")
sar_pddl_state = State()
sar_pddl_plan, plan_time = sar_pddl_planner.get_plan(sar_pddl_state)
result = execute_plan(problem=sar_pddl_problem, state=sar_pddl_state, plan=sar_pddl_plan)
# Out:
#             <div style="margin-bottom:16px; border:1px solid #ddd; padding:8px;">
#                 <input type="range" id="b11fd38d_a782_46d0_8a46_f3c015a5c5f3_slider" min="0" max="110" value="0" style="width:100%">
#                 <div id="b11fd38d_a782_46d0_8a46_f3c015a5c5f3_label" style="font-family: sans-serif; margin-top:4px; font-size: 14px;">
#                     Render 1 of 111
#                 </div>
#                 <pre id="b11fd38d_a782_46d0_8a46_f3c015a5c5f3_container" style="font-family: monospace; white-space: pre; border:1px solid #ccc; padding:10px; margin-top:8px;"></pre>
#             </div>
#             <script>
#                 const states_b11fd38d_a782_46d0_8a46_f3c015a5c5f3 = [`execute_plan: down
# ##################
# ##Ro          p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`execute_plan: down
# ##################
# ##            p3##
# ##Ro####    ######
# ##              ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`execute_plan: down
# ##################
# ##            p3##
# ##  ####    ######
# ##Ro            ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`execute_plan: down
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##Ro  ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`execute_plan: pickup-p1
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##R1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`execute_plan: down
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##Ro  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: p1
# `,`execute_plan: dropoff
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##Ro        ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: p1
# `,`execute_plan: down
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##R1        ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`execute_plan: pickup-p2
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##p1        ##  ##
# ##R2##    ##  Ho##
# ##################
# Carrying: None
# `,`execute_plan: up
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##p1        ##  ##
# ##Ro##    ##  Ho##
# ##################
# Carrying: p2
# `,`execute_plan: right
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##R1        ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p2
# `,`execute_plan: dropoff
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##p1Ro      ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p2
# `,`execute_plan: left
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##p1R2      ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: None
# `,`execute_plan: pickup-p1
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##R1p2      ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: None
# `,`execute_plan: right
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##Rop2      ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p1
# `,`execute_plan: right
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##  R2      ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p1
# `,`execute_plan: dropoff
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##  p2Ro    ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p1
# `,`execute_plan: left
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##  p2R1    ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: None
# `,`execute_plan: pickup-p2
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##  R2p1    ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: None
# `,`execute_plan: right
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##  Rop1    ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p2
# `,`execute_plan: right
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##    R1    ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p2
# `,`execute_plan: dropoff
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##    p1Ro  ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p2
# `,`execute_plan: left
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##    p1R2  ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: None
# `,`execute_plan: pickup-p1
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##    R1p2  ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: None
# `,`execute_plan: right
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##    Rop2  ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p1
# `,`execute_plan: up
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##      R2  ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p1
# `,`execute_plan: dropoff
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##Ro##    ##
# ##      p2  ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p1
# `,`execute_plan: down
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##R1##    ##
# ##      p2  ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: None
# `,`execute_plan: pickup-p2
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##p1##    ##
# ##      R2  ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: None
# `,`execute_plan: up
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##p1##    ##
# ##      Ro  ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p2
# `,`execute_plan: up
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##R1##    ##
# ##          ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p2
# `,`execute_plan: dropoff
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##R4      ##
# ##    ##p1##    ##
# ##          ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p2
# `,`execute_plan: down
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##R2      ##
# ##    ##p1##    ##
# ##          ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: None
# `,`execute_plan: pickup-p1
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p2      ##
# ##    ##R1##    ##
# ##          ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: None
# `,`execute_plan: up
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p2      ##
# ##    ##Ro##    ##
# ##          ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p1
# `,`exe

# %%
# Test 3
Grader.run_single_test_inline(TestProj1, "test_03_sar_pddl", locals())
# Out:
# <div class="alert alert-success">
#         <strong>Test passed!!</strong>
#         </div>
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.002s
#
# OK

# %% [markdown]
# ## <a id="inference"></a> 2. Inference from Observations (20 points)

# %% [markdown]
# The real world is **partially observable**, where the robot can only see part of the world at a time. To handle this, we introduce the idea of a **belief**. A belief is simply the robot’s current knowledge about the world. It may include some unknowns, and as the robot moves and makes observations, the belief gets updated. In this project, a belief will look like the grid maps you’ve seen already, except with `"U"` entries for unknown cells. As the robot observes cells, `"U"` entries will be replaced with `"C"`, `"F"`, `"S"`, or `"W"`. We will also use logical rules (inference) to fill in what must be true.
#
# Now, let's look at the inference problem.  This is similar to the problem we saw in PSet 3. We will consider several problems with varying grid sizes and different sets of observations. For example, consider the grid below:
# ```
# # Fire, Unknown, Clear, Smoke, Wall
# GRID0 = np.array([
#   ["F", "U", "C"],
#   ["W", "C", "U"],
#   ["U", "U", "C"]
# ], dtype=object)
# ```
# This grid has 9 locations and 5 observations: there is fire in the top left, wall below it, and the center, top right, and bottom right locations are all known to be clear of smoke or fire.
#
# We will assume the following axioms:
# 1. Each location has exactly one of {smoke, fire, clear, wall}.
#
# 2. There is smoke at a location only if there is a fire in at least one of the adjacent (above, below, left, right) locations. Diagonals are not adjacent!
#
# 3. There is smoke _or_ fire at a location if there is a fire in at least one of the adjacent locations, unless it's known to be 'W'.
#
# Take a moment to run your human inference engine: which unknown values in the grid above can be determined?

# %% [markdown]
# ### <a id="infer_unknowns"></a> 2A. Inferring unknown values (10 points)
#
# Please write a program that takes a grid as input and infers unknown values.
#
# Your program should output a new grid with all determinable unknown values replaced with the inferred value. If an unknown value cannot be determined, it should be left unknown.
#
# **Your program should use sympy.**
#
# For reference, our solution is **63** line(s) of code.

# %%
def infer_unknown_values(grid):
    """Fill in any unknown values in the grid that can be inferred.

    Args: grid: A list of lists of "F", "U", "S", "W", or "C".
    Returns:
      inferred_grid: A copy of grid with some unknown values replaced.

    Example:
      >> grid = [
      >>   ["F", "U", "C"],
      >>   ["W", "C", "U"],
      >>   ["U", "U", "C"]
      >> ]
      >> infer_unknown_values(grid)
      >> [["F" "S" "C"]
      >>  ["W" "C" "C"]
      >>  ["U" "U" "C"]]
    """
    from sympy import Symbol, And, Or, Not, satisfiable

    H = len(grid)
    W = len(grid[0]) if H else 0

    # Boolean variables per cell and label
    Fv, Sv, Cv, Wv = {}, {}, {}, {}
    for r in range(H):
        for c in range(W):
            Fv[(r, c)] = Symbol(f"F_{r}_{c}")
            Sv[(r, c)] = Symbol(f"S_{r}_{c}")
            Cv[(r, c)] = Symbol(f"C_{r}_{c}")
            Wv[(r, c)] = Symbol(f"W_{r}_{c}")

    constraints = []

    # Axiom 1: Exactly one of {F,S,C,W} at each cell
    for r in range(H):
        for c in range(W):
            vals = [Fv[(r, c)], Sv[(r, c)], Cv[(r, c)], Wv[(r, c)]]
            constraints.append(Or(*vals))  # at least one
            for i in range(4):             # at most one (pairwise)
                for j in range(i + 1, 4):
                    constraints.append(Or(Not(vals[i]), Not(vals[j])))

    # Observations + "walls known in advance" (unknowns cannot be walls)
    for r in range(H):
        for c in range(W):
            v = grid[r][c]
            if v in ("F", "S", "C", "W"):
                constraints.append({"F": Fv, "S": Sv, "C": Cv, "W": Wv}[v][(r, c)])
            if v != "W":
                constraints.append(Not(Wv[(r, c)]))  # disallow walls unless observed

    def neighbors(rr, cc):
        for dr, dc in [(-1, 0), (1, 0), (0, -1), (0, 1)]:
            nr, nc = rr + dr, cc + dc
            if 0 <= nr < H and 0 <= nc < W:
                yield nr, nc

    # Axiom 2: S(i) -> (exists neighbor with F)
    for r in range(H):
        for c in range(W):
            neigh = [Fv[n] for n in neighbors(r, c)]
            neigh_or = Or(*neigh) if neigh else False
            constraints.append(Or(Not(Sv[(r, c)]), neigh_or))

    # Axiom 3 (knowledge-based): if any neighbor has F, then (S or F) here,
    # applied to every cell that is NOT *observed* as a wall.
    for r in range(H):
        for c in range(W):
            if grid[r][c] != "W":  # exempt only observed walls
                neigh = [Fv[n] for n in neighbors(r, c)]
                neigh_or = Or(*neigh) if neigh else False
                constraints.append(Or(Not(neigh_or), Or(Sv[(r, c)], Fv[(r, c)])))

    formula = And(*constraints)

    # Infer: for each U, find the unique label that yields a satisfiable model
    out = [row[:] for row in grid]
    for r in range(H):
        for c in range(W):
            if grid[r][c] == "U":
                candidates = []
                for label, varmap in [("F", Fv), ("S", Sv), ("C", Cv), ("W", Wv)]:
                    if satisfiable(And(formula, varmap[(r, c)]), all_models=False):
                        candidates.append(label)
                if len(candidates) == 1:
                    out[r][c] = candidates[0]
    return out

# %%
# Note: we're providing these unit tests to help you. 
# The grading tests are not just these tests.

assert infer_unknown_values([["U", "F"]]) == [["U", "F"]]
assert infer_unknown_values([["F", "U", "C"], ["S", "C", "U"], ["U", "U", "C"]]) == [["F", "S", "C"], ["S", "C", "C"], ["U", "U", "C"]]
assert infer_unknown_values([["U", "C", "C"], ["S", "C", "U"], ["U", "U", "C"]]) == [["C", "C", "C"], ["S", "C", "C"], ["F", "S", "C"]]
assert infer_unknown_values([["U", "S", "C", "U"], ["U", "U", "C", "U"], ["U", "S", "C", "U"]]) == [["F", "S", "C", "C"], ["U", "U", "C", "C"], ["F", "S", "C", "C"]]
assert infer_unknown_values([["U", "U", "C", "U", "U", "U", "U", "U"], ["C", "U", "U", "U", "U", "U", "U", "U"], ["U", "U", "U", "U", "U", "U", "U", "U"], ["U", "U", "U", "U", "U", "U", "C", "C"], ["U", "U", "U", "U", "U", "U", "C", "C"], ["U", "C", "U", "U", "U", "U", "U", "U"], ["U", "U", "U", "F", "U", "U", "U", "U"], ["U", "U", "U", "U", "U", "U", "U", "U"]]) == [["C", "C", "C", "U", "U", "U", "U", "U"], ["C", "U", "U", "U", "U", "U", "U", "U"], ["U", "U", "U", "U", "U", "U", "U", "U"], ["U", "U", "U", "U", "U", "U", "C", "C"], ["U", "U", "U", "U", "U", "U", "C", "C"], ["U", "C", "U", "U", "U", "U", "U", "U"], ["U", "U", "U", "F", "U", "U", "U", "U"], ["U", "U", "U", "U", "U", "U", "U", "U"]]
assert infer_unknown_values([["C", "U", "C", "U", "U", "C", "U"], ["U", "W", "W", "U", "C", "W", "W"], ["U", "F", "U", "U", "U", "F", "U"], ["C", "S", "W", "C", "U", "U", "U"], ["U", "U", "W", "U", "W", "U", "U"], ["C", "C", "U", "C", "U", "W", "U"], ["U", "W", "C", "U", "W", "U", "C"]]) == [["C", "C", "C", "C", "C", "C", "C"], ["C", "W", "W", "C", "C", "W", "W"], ["S", "F", "U", "U", "S", "F", "U"], ["C", "S", "W", "C", "U", "U", "U"], ["C", "C", "W", "C", "W", "U", "U"], ["C", "C", "C", "C", "C", "W", "U"], ["C", "W", "C", "C", "W", "C", "C"]]
assert infer_unknown_values([["C", "U", "C", "U", "U", "C", "U"], ["U", "W", "W", "U", "C", "W", "W"], ["U", "F", "U", "U", "U", "F", "U"], ["C", "S", "W", "C", "U", "F", "U"], ["U", "U", "W", "U", "W", "U", "U"], ["C", "C", "U", "C", "U", "W", "F"], ["U", "W", "C", "U", "W", "U", "U"]]) == [["C", "C", "C", "C", "C", "C", "C"], ["C", "W", "W", "C", "C", "W", "W"], ["S", "F", "U", "U", "S", "F", "U"], ["C", "S", "W", "C", "S", "F", "U"], ["C", "C", "W", "C", "W", "U", "U"], ["C", "C", "C", "C", "C", "W", "F"], ["C", "W", "C", "C", "W", "U", "U"]]
print('Tests passed.')
# Out:
# Tests passed.

# %%
# Test 4
Grader.run_single_test_inline(TestProj1, "test_04_infer_unknown", locals())
# Out:
# <div class="alert alert-success">
#         <strong>Test passed!!</strong>
#         </div>
# .
# ----------------------------------------------------------------------
# Ran 1 test in 13.607s
#
# OK

# %% [markdown]
# ### <a id="belief_update"></a> 2B. Belief update (10 points)

# %% [markdown]
# When the robot acts in the environment, its knowledge must change in three ways:
# 1. **Transition step** – move the robot’s position forward based on the chosen action
#    (e.g., if the action is `down`, the robot moves one square down).
# 2. **Observation step** – incorporate any new sensor information about nearby cells.
# 3. **Inference step** – apply logical rules to replace `"U"` with `"C"`, `"F"`, or `"S"`
#    wherever those values can be deduced.
#
# This process is called a **belief update**. It is nothing more than keep track of what the robot now knows after acting and looking around.
#
# Now let us use our ability to infer unknown values to finish the implementation of the update method for BeliefState.
#
# Make sure to look at the utilities defined at the top of this notebook, although you may not need to use all of them.
#
# For reference, our solution is **12** line(s) of code.

# %%
class BeliefState(State):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        if "state_map" not in kwargs:
            self.state_map = np.array([['U', 'U', 'U', 'U', 'U', 'U', 'U'],
                                       ['U', 'W', 'W', 'U', 'U', 'W', 'W'],
                                       ['U', 'U', 'U', 'U', 'U', 'U', 'U'],
                                       ['U', 'U', 'W', 'U', 'U', 'U', 'U'],
                                       ['U', 'U', 'W', 'U', 'W', 'U', 'U'],
                                       ['U', 'U', 'U', 'U', 'U', 'W', 'U'],
                                       ['U', 'W', 'U', 'U', 'W', 'U', 'U']],
                                      dtype=str)

    def update(self, problem, obs, action=None):
        """
        problem: SearchAndRescueProblem instance
        obs: {loc: entry, loc: entry,...}
        act: string or None

        # <<< TODO: >>>
            1. Do transition from action (if any)
            2. Update from observation
            3. Do inference
        """
        new_belief = self.copy()
        
        # 1. Do transition from action
        if action is not None:
            new_belief, _ = problem.get_next_state(new_belief, action)
        
        # 2. Update from observation
        for loc, value in obs.items():
            new_belief.state_map[loc] = value
        
        # 3. Do inference
        new_belief.state_map = np.array(infer_unknown_values(new_belief.state_map.tolist()))
        
        return new_belief

    def get_optimistic_state(self):
        """Returns a copy of the belief with a completed map in which Unknowns
        are assumed to be Clear."""
        new_state = self.copy()
        new_state.state_map[self.state_map == 'U'] = 'C'
        return new_state

    def get_careful_state(self):
        """Returns a copy of the belief.

        Unknown states will not be treated as safe, see get_safe_grid.
        """
        return self.copy()

# %% [markdown]
# ### Tests

# %%
def beliefupdate_test1():
    state_map = np.array([["C", "S", "C", "C", "C"], ["S", "F", "S", "C", "C"],
                          ["S", "F", "S", "S", "S"], ["S", "F", "F", "F", "F"],
                          ["C", "S", "S", "S", "S"], ["C", "C", "C", "C", "C"]])
    beliefstate_map = np.array([["U", "U", "U", "U", "U"],
                                ["U", "U", "U", "U", "U"],
                                ["U", "U", "U", "U", "U"],
                                ["U", "U", "U", "U", "U"],
                                ["U", "U", "U", "U", "U"],
                                ["U", "U", "U", "U", "U"]])
    problem = SearchAndRescueProblem()
    state = State(state_map=state_map)
    bel = BeliefState(state_map=beliefstate_map)
    observation = problem.get_observation(state)
    new_bel = bel.update(problem, observation)
    assert new_bel.robot == (0, 0)
    assert new_bel.state_map.tolist() == [['C', 'S', 'U', 'U', 'U'],
                                          ['S', 'U', 'U', 'U', 'U'],
                                          ['U', 'U', 'U', 'U', 'U'],
                                          ['U', 'U', 'U', 'U', 'U'],
                                          ['U', 'U', 'U', 'U', 'U'],
                                          ['U', 'U', 'U', 'U', 'U']]
beliefupdate_test1()


def beliefupdate_test2():
    state_map = np.array([["C", "S", "C", "C", "C"], ["S", "F", "S", "C", "C"],
                          ["S", "F", "S", "S", "S"], ["S", "F", "F", "F", "F"],
                          ["C", "S", "S", "S", "S"], ["C", "C", "C", "C", "C"]])
    beliefstate_map = np.array([["U", "U", "U", "U", "U"],
                                ["S", "U", "U", "U", "U"],
                                ["U", "U", "U", "U", "U"],
                                ["U", "U", "U", "U", "U"],
                                ["U", "U", "U", "U", "U"],
                                ["U", "U", "U", "U", "U"]])
    problem = SearchAndRescueProblem()
    state = State(state_map=state_map)
    bel = BeliefState(state_map=beliefstate_map)

    new_state, _ = problem.get_next_state(state, 'down')
    observation = problem.get_observation(new_state)
    new_bel = bel.update(problem, observation, 'down')
    assert new_bel.robot == (1, 0)
    assert new_bel.state_map.tolist() == [['C', 'S', 'U', 'U', 'U'],
                                          ['S', 'F', 'U', 'U', 'U'],
                                          ['S', 'U', 'U', 'U', 'U'],
                                          ['U', 'U', 'U', 'U', 'U'],
                                          ['U', 'U', 'U', 'U', 'U'],
                                          ['U', 'U', 'U', 'U', 'U']]
beliefupdate_test2()

# %%
# Test 5
Grader.run_single_test_inline(TestProj1, "test_05_belief_update", locals())
# Out:
# <div class="alert alert-success">
#         <strong>Test passed!!</strong>
#         </div>
# .
# ----------------------------------------------------------------------
# Ran 1 test in 3.406s
#
# OK

# %% [markdown]
# ## <a id="integrated"></a> 3. Putting It Together (35 points)
#
# It's time to bring the planning and the inference together! Look at the procedure `agent_loop` that takes as input:
#
# * "initial_state": (a true state of the environment, which includes a state map, as well as the current locations of the hospital, the robot and the people and whether the robot is carrying someone.
# * "initial_belief" (an initial belief state, which is like an environment state, except that the state map may include characters 'U' indicating that the contents of a location is unknown)
# * "policy" : a procedure that takes in a belief state and returns the next action to take;  the action can be one of the original actions or '*Success*' (which means the goal has been achieved and all the people are at the hospital) or '*Failure*' (which means that the agent is certain that the goal is impossible to achieve.)
# * "max_steps" : just a total number of steps to run the simulation to avoid infinite loops
#
# We are going to ask you to write five different policies for this domain.
#
# 1. Safe but not so smart
# 1. Safe and smart
# 1. Reckless
# 1. Safe and smart if possible, else reckless
# 1. Looks before it leaps
#
# ### <a id="safe_no_smart"></a> 3A. Safe but not so smart (7 points)
#
# The agent is scared and just running directly to the hospital. However, it at least takes observations into account as it moves.
#
# Let's make an agent that:
#
# * Updates the belief state based on every observation using propositional inference (implement the `belief.update` method that gets called in `agent_loop`).
#
# * Executes a policy that, given the currently updated belief, checks to see whether it can move safely into a square that is closer (in Manhattan distance) to the hospital.  If so, it returns the action that would move it closer.  If it reaches the hospital, it returns `*Success*`.  If it cannot safely make a move (due to walls or fire) closer to the hospital, it waves its arms in anguish and returns `*Failure*`.
#
# For reference, our solution is **18** line(s) of code.

# %%
def make_greedy_policy(problem):
    def policy(belief):
        """Returns an action or '*Failure*"""
        robot_r, robot_c = belief.robot
        hosp_r, hosp_c = belief.hospital
        
        # Check if at hospital
        if (robot_r, robot_c) == (hosp_r, hosp_c):
            return '*Success*'
        
        # Try to move closer to hospital
        safe_grid = belief.get_safe_grid()
        
        # Calculate distances
        moves = []
        for action, (dr, dc) in problem.action_deltas.items():
            new_r, new_c = robot_r + dr, robot_c + dc
            # Check if valid and safe
            if (0 <= new_r < safe_grid.shape[0] and 
                0 <= new_c < safe_grid.shape[1] and 
                safe_grid[new_r, new_c]):
                new_dist = abs(hosp_r - new_r) + abs(hosp_c - new_c)
                moves.append((new_dist, action))
        
        if not moves:
            return '*Failure*'
        
        # Return action that minimizes distance
        moves.sort()
        return moves[0][1]

    # return the policy function
    return policy

# %% [markdown]
# In a completely clear map, the robot should be able to make it to the hospital.

# %%
def greedy_in_empty_map():
    problem = SearchAndRescueProblem()
    policy = make_greedy_policy(problem)

    # Empty map
    state = State()
    state.state_map[:, :] = 'C'
    bel = BeliefState()
    bel.state_map[:, :] = 'C'

    s_or_f, final_state, final_bel = agent_loop(problem, state, policy, bel)
    print('Final robot location', final_state.robot)
    return s_or_f, final_state, final_bel

greedy_in_empty_result = greedy_in_empty_map()
# Out:
#             <div style="margin-bottom:16px; border:1px solid #ddd; padding:8px;">
#                 <input type="range" id="2f0b2cbf_4b96_4105_b2d3_f1449c370087_slider" min="0" max="12" value="0" style="width:100%">
#                 <div id="2f0b2cbf_4b96_4105_b2d3_f1449c370087_label" style="font-family: sans-serif; margin-top:4px; font-size: 14px;">
#                     Render 1 of 13
#                 </div>
#                 <pre id="2f0b2cbf_4b96_4105_b2d3_f1449c370087_container" style="font-family: monospace; white-space: pre; border:1px solid #ccc; padding:10px; margin-top:8px;"></pre>
#             </div>
#             <script>
#                 const states_2f0b2cbf_4b96_4105_b2d3_f1449c370087 = [`Initial state
# ##################
# ##Ro          p3##
# ##              ##
# ##              ##
# ##      p4      ##
# ##p1            ##
# ##              ##
# ##p2          Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 0, action down
# Observation {(1, 0): np.str_('C'), (0, 0): np.str_('C'), (2, 0): np.str_('C'), (1, 1): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##Ro            ##
# ##              ##
# ##      p4      ##
# ##p1            ##
# ##              ##
# ##p2          Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 1, action down
# Observation {(2, 0): np.str_('C'), (1, 0): np.str_('C'), (3, 0): np.str_('C'), (2, 1): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##              ##
# ##Ro            ##
# ##      p4      ##
# ##p1            ##
# ##              ##
# ##p2          Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 2, action down
# Observation {(3, 0): np.str_('C'), (2, 0): np.str_('C'), (4, 0): np.str_('C'), (3, 1): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##              ##
# ##              ##
# ##Ro    p4      ##
# ##p1            ##
# ##              ##
# ##p2          Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 3, action down
# Observation {(4, 0): np.str_('C'), (3, 0): np.str_('C'), (5, 0): np.str_('C'), (4, 1): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##              ##
# ##              ##
# ##      p4      ##
# ##R1            ##
# ##              ##
# ##p2          Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 4, action down
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##              ##
# ##              ##
# ##      p4      ##
# ##p1            ##
# ##Ro            ##
# ##p2          Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 5, action down
# Observation {(6, 0): np.str_('C'), (5, 0): np.str_('C'), (6, 1): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##              ##
# ##              ##
# ##      p4      ##
# ##p1            ##
# ##              ##
# ##R2          Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 6, action right
# Observation {(6, 1): np.str_('C'), (5, 1): np.str_('C'), (6, 0): np.str_('C'), (6, 2): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##              ##
# ##              ##
# ##      p4      ##
# ##p1            ##
# ##              ##
# ##p2Ro        Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 7, action right
# Observation {(6, 2): np.str_('C'), (5, 2): np.str_('C'), (6, 1): np.str_('C'), (6, 3): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##              ##
# ##              ##
# ##      p4      ##
# ##p1            ##
# ##              ##
# ##p2  Ro      Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 8, action right
# Observation {(6, 3): np.str_('C'), (5, 3): np.str_('C'), (6, 2): np.str_('C'), (6, 4): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##              ##
# ##              ##
# ##      p4      ##
# ##p1            ##
# ##              ##
# ##p2    Ro    Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 9, action right
# Observation {(6, 4): np.str_('C'), (5, 4): np.str_('C'), (6, 3): np.str_('C'), (6, 5): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##              ##
# ##              ##
# ##      p4      ##
# ##p1            ##
# ##              ##
# ##p2      Ro  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 10, action right
# Observation {(6, 5): np.str_('C'), (5, 5): np.str_('C'), (6, 4): np.str_('C'), (6, 6): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##              ##
# ##              ##
# ##      p4      ##
# ##p1            ##
# ##              ##
# ##p2        RoHo##
# ##################
# Carrying: None
# `,`agent_loop: step 11, action right
# Observation {(6, 6): np.str_('C'), (5, 6): np.str_('C'), (6, 5): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##              ##
# ##              ##
# ##      p4      ##
# ##p1            ##
# ##              ##
# ##p2          Ro##
# ##################
# Carrying: None
# `];
#                 const slider_2f0b2cbf_4b96_4105_b2d3_f1449c370087 = document.getElementById("2f0b2cbf_4b96_4105_b2d3_f1449c370087_slider");
#                 const container_2f0b2cbf_4b96_4105_b2d3_f1449c370087 = document.getElementById("2f0b2cbf_4b96_4105_b2d3_f1449c370087_container");
#                 const label_2f0b2cbf_4b96_4105_b2d3_f1449c370087 = document.getElementById("2f0b2cbf_4b96_4105_b2d3_f1449c370087_label");
#
#                 function update_2f0b2cbf_4b96_4105_b2d3_f1449c370087() {
#                     const i = parseInt(slider_2f0b2cbf_4b96_4105_b2d3_f1449c370087.value, 10);
#                     container_2f0b2cbf_4b96_4105_b2d3_f1449c370087.textContent = states_2f0b2cbf_4b96_4105_b2d3_f1449c370087[i];
#                     label_2f0b2cbf_4b96_4105_b2d3_f1449c370087.textContent = "Render " + (i+1) + " of 13";
#                 }
#
#                 slider_2f0b2cbf_4b96_4105_b2d3_f1449c370087.addEventListener("input", update_2f0b2cbf_4b96_4105_b2d3_f1449c370087);
#                 update_2f0b2cbf_4b96_4105_b2d3_f1449c370087();  // initialize
#             </script>
#             <div style="margin-bottom:16px; border:1px solid #ddd; padding:8px;">
#                 <input type="range" id="a074edce_36f9_48f7_b9b9_09aab3546e7d_slider" min="0" max="13" value="0" style="width:100%">
#                 <div id="a074edce_36f9_48f7_b9b9_09aab3546e7d_label" style="font-family: sans-serif; margin-top:4px; font-size: 14px;">
#                     Render 1 of 14
#                 </div>
#                 <pre id="a074edce_36f9_48f7_b9b9_09aab3546e7d_container" style="font-family: monospace; white-space: pre; border:1px solid #ccc; padding:10px; margin-top:8px;"></pre>
#             </div>
#             <script>
#                 const states_a074edce_36f9_48f7_b9b9_09aab3546e7d = [`Initial belief
# ##################
# ##Ro          p3##
# ##              ##
# ##              ##
# ##      p4      ##
# ##p1            ##
# ##              ##
# ##p2          Ho##
# ##################
# Carrying: None
# `,`Initial observation {(0, 0): np.str_('C'), (1, 0): np.str_('C'), (0, 1): np.str_('C')}
# New belief
# ##################
# ##Ro          p3##
# ##              ##
# ##              ##
# ##      p4      ##
# ##p1            ##
# ##              ##
# ##p2          Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 0, action down
# Observation {(1, 0): np.str_('C'), (0, 0): np.str_('C'), (2, 0): np.str_('C'), (1, 1): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##Ro            ##
# ##              ##
# ##      p4      ##
# ##p1            ##
# ##              ##
# ##p2          Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 1, action down
# Observation {(2, 0): np.str_('C'), (1, 0): np.str_('C'), (3, 0): np.str_('C'), (2, 1): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##              ##
# ##Ro            ##
# ##      p4      ##
# ##p1            ##
# ##              ##
# ##p2          Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 2, action down
# Observation {(3, 0): np.str_('C'), (2, 0): np.str_('C'), (4, 0): np.str_('C'), (3, 1): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##              ##
# ##              ##
# ##Ro    p4      ##
# ##p1            ##
# ##              ##
# ##p2          Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 3, action down
# Observation {(4, 0): np.str_('C'), (3, 0): np.str_('C'), (5, 0): np.str_('C'), (4, 1): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##              ##
# ##              ##
# ##      p4      ##
# ##R1            ##
# ##              ##
# ##p2          Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 4, action down
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##              ##
# ##              ##
# ##      p4      ##
# ##p1            ##
# ##Ro            ##
# ##p2          Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 5, action down
# Observation {(6, 0): np.str_('C'), (5, 0): np.str_('C'), (6, 1): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##              ##
# ##              ##
# ##      p4      ##
# ##p1            ##
# ##              ##
# ##R2          Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 6, action right
# Observation {(6, 1): np.str_('C'), (5, 1): np.str_('C'), (6, 0): np.str_('C'), (6, 2): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##              ##
# ##              ##
# ##      p4      ##
# ##p1            ##
# ##              ##
# ##p2Ro        Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 7, action right
# Observation {(6, 2): np.str_('C'), (5, 2): np.str_('C'), (6, 1): np.str_('C'), (6, 3): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##              ##
# ##              ##
# ##      p4      ##
# ##p1            ##
# ##              ##
# ##p2  Ro      Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 8, action right
# Observation {(6, 3): np.str_('C'), (5, 3): np.str_('C'), (6, 2): np.str_('C'), (6, 4): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##              ##
# ##              ##
# ##      p4      ##
# ##p1            ##
# ##              ##
# ##p2    Ro    Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 9, action right
# Observation {(6, 4): np.str_('C'), (5, 4): np.str_('C'), (6, 3): np.str_('C'), (6, 5): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##              ##
# ##              ##
# ##      p4      ##
# ##p1            ##
# ##              ##
# ##p2      Ro  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 10, action right
# Observation {(6, 5): np.str_('C'), (5, 5): np.str_('C'), (6, 4): np.str_('C'), (6, 6): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##              ##
# ##              ##
# ##      p4      ##
# ##p1            ##
# ##              ##
# ##p2        RoHo##
# ##################
# Carrying: None
# `,`agent_loop: step 11, action right
# Observation {(6, 6): np.str_('C'), (5, 6): np.str_('C'), (6, 5): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##              ##
# ##              ##
# ##      p4      ##
# ##p1            ##
# ##              ##
# ##p2          Ro##
# ##################
# Carrying: None
# `];
#                 const slider_a074edce_36f9_48f7_b9b9_09aab3546e7d = document.getElementById("a074edce_36f9_48f7_b9b9_09aab3546e7d_slider");
#                 const container_a074edce_36f9_48f7_b9b9_09aab3546e7d = document.getElementById("a074edce_36f9_48f7_b9b9_09aab3546e7d_container");
#                 const label_a074edce_36f9_48f7_b9b9_09aab3546e7d = document.getElementById("a074edce_36f9_48f7_b9b9_09aab3546e7d_label");
#
#                 function update_a074edce_36f9_48f7_b9b9_09aab3546e7d() {
#                     const i = parseInt(slider_a074edce_36f9_48f7_b9b9_09aab3546e7d.value, 10);
#                     container_a074edce_36f9_48f7_b9b9_09aab3546e7d.textContent = states_a074edce_36f9_48f7_b9b9_09aab3546e7d[i];
#                     label_a074edce_36f9_48f7_b9b9_09aab3546e7d.textContent = "Render " + (i+1) + " of 14";
#                 }
#
#                 slider_a074edce_36f9_48f7_b9b9_09aab3546e7d.addEventListener("input", update_a074edce_36f9_48f7_b9b9_09aab3546e7d);
#                 update_a074edce_36f9_48f7_b9b9_09aab3546e7d();  // initialize
#             </script>
# Terminate with *Success*
# Final robot location (6, 6)

# %% [markdown]
# Using our default map, the robot should at least make it a bit closer to the hospital.

# %%
def greedy_in_default():
    problem = SearchAndRescueProblem()

    # Use default map
    state = State()
    bel = BeliefState()

    policy = make_greedy_policy(problem)
    s_or_f, final_state, final_bel = agent_loop(problem, state, policy, bel)
    r, c = final_state.robot
    hr, hc = final_state.hospital
    distance = abs(hr - r) + abs(hc - c)
    print('Final robot location', final_state.robot)
    print('Final distance (should be < initial distance) =', distance)
    return distance 

greedy_in_default_distance = greedy_in_default()
# Out:
#             <div style="margin-bottom:16px; border:1px solid #ddd; padding:8px;">
#                 <input type="range" id="73eb5230_4f97_48df_89bc_f4c138759145_slider" min="0" max="200" value="0" style="width:100%">
#                 <div id="73eb5230_4f97_48df_89bc_f4c138759145_label" style="font-family: sans-serif; margin-top:4px; font-size: 14px;">
#                     Render 1 of 201
#                 </div>
#                 <pre id="73eb5230_4f97_48df_89bc_f4c138759145_container" style="font-family: monospace; white-space: pre; border:1px solid #ccc; padding:10px; margin-top:8px;"></pre>
#             </div>
#             <script>
#                 const states_73eb5230_4f97_48df_89bc_f4c138759145 = [`Initial state
# ##################
# ##Ro          p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 0, action down
# Observation {(1, 0): np.str_('C'), (0, 0): np.str_('C'), (2, 0): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##Ro####    ######
# ##              ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 1, action down
# Observation {(2, 0): np.str_('C'), (1, 0): np.str_('C'), (3, 0): np.str_('C'), (2, 1): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##Ro            ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 2, action down
# Observation {(3, 0): np.str_('C'), (2, 0): np.str_('C'), (4, 0): np.str_('C'), (3, 1): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##Ro  ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 3, action down
# Observation {(4, 0): np.str_('C'), (3, 0): np.str_('C'), (5, 0): np.str_('C'), (4, 1): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##R1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 4, action down
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##Ro        ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 5, action down
# Observation {(6, 0): np.str_('C'), (5, 0): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##R2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 6, action up
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##Ro        ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 7, action down
# Observation {(6, 0): np.str_('C'), (5, 0): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##R2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 8, action up
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##Ro        ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 9, action down
# Observation {(6, 0): np.str_('C'), (5, 0): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##R2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 10, action up
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##Ro        ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 11, action down
# Observation {(6, 0): np.str_('C'), (5, 0): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##R2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 12, action up
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##Ro        ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 13, action down
# Observation {(6, 0): np.str_('C'), (5, 0): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##R2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 14, action up
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##Ro        ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 15, action down
# Observation {(6, 0): np.str_('C'), (5, 0): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##R2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 16, action up
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##Ro        ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 17, action down
# Observation {(6, 0): np.str_('C'), (5, 0): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##R2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 18, action up
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##Ro        ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 19, action down
# Observation {(6, 0): np.str_('C'), (5, 0): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##R2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 20, action up
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##Ro        ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 21, action down
# Observation {(6, 0): np.str_('C'), (5, 0): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##R2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 22, action up
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##
#             <div style="margin-bottom:16px; border:1px solid #ddd; padding:8px;">
#                 <input type="range" id="c552af8b_62bd_4ea6_b35d_2a85c0362107_slider" min="0" max="201" value="0" style="width:100%">
#                 <div id="c552af8b_62bd_4ea6_b35d_2a85c0362107_label" style="font-family: sans-serif; margin-top:4px; font-size: 14px;">
#                     Render 1 of 202
#                 </div>
#                 <pre id="c552af8b_62bd_4ea6_b35d_2a85c0362107_container" style="font-family: monospace; white-space: pre; border:1px solid #ccc; padding:10px; margin-top:8px;"></pre>
#             </div>
#             <script>
#                 const states_c552af8b_62bd_4ea6_b35d_2a85c0362107 = [`Initial belief
# ##################
# ##Ro??????????p3##
# ##??####????######
# ##??????????????##
# ##????##p4??????##
# ##p1??##??##????##
# ##??????????##??##
# ##p2##????##??Ho##
# ##################
# Carrying: None
# `,`Initial observation {(0, 0): np.str_('C'), (1, 0): np.str_('C'), (0, 1): np.str_('C')}
# New belief
# ##################
# ##Ro  ????????p3##
# ##  ####????######
# ##??????????????##
# ##????##p4??????##
# ##p1??##??##????##
# ##??????????##??##
# ##p2##????##??Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 0, action down
# Observation {(1, 0): np.str_('C'), (0, 0): np.str_('C'), (2, 0): np.str_('C')}
# New belief
# ##################
# ##    ????????p3##
# ##Ro####????######
# ##  ????????????##
# ##????##p4??????##
# ##p1??##??##????##
# ##??????????##??##
# ##p2##????##??Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 1, action down
# Observation {(2, 0): np.str_('C'), (1, 0): np.str_('C'), (3, 0): np.str_('C'), (2, 1): np.str_('C')}
# New belief
# ##################
# ##    ????????p3##
# ##  ####????######
# ##Ro  ??????????##
# ##  ??##p4??????##
# ##p1??##??##????##
# ##??????????##??##
# ##p2##????##??Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 2, action down
# Observation {(3, 0): np.str_('C'), (2, 0): np.str_('C'), (4, 0): np.str_('C'), (3, 1): np.str_('C')}
# New belief
# ##################
# ##    ????????p3##
# ##  ####????######
# ##    ??????????##
# ##Ro  ##p4??????##
# ##p1??##??##????##
# ##??????????##??##
# ##p2##????##??Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 3, action down
# Observation {(4, 0): np.str_('C'), (3, 0): np.str_('C'), (5, 0): np.str_('C'), (4, 1): np.str_('C')}
# New belief
# ##################
# ##    ????????p3##
# ##  ####????######
# ##    ??????????##
# ##    ##p4??????##
# ##R1  ##??##????##
# ##  ????????##??##
# ##p2##????##??Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 4, action down
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New belief
# ##################
# ##    ????????p3##
# ##  ####????######
# ##    ??????????##
# ##    ##p4??????##
# ##p1  ##??##????##
# ##Ro  ??????##??##
# ##p2##????##??Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 5, action down
# Observation {(6, 0): np.str_('C'), (5, 0): np.str_('C')}
# New belief
# ##################
# ##    ????????p3##
# ##  ####????######
# ##    ??????????##
# ##    ##p4??????##
# ##p1  ##??##????##
# ##    ??????##??##
# ##R2##????##??Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 6, action up
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New belief
# ##################
# ##    ????????p3##
# ##  ####????######
# ##    ??????????##
# ##    ##p4??????##
# ##p1  ##??##????##
# ##Ro  ??????##??##
# ##p2##????##??Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 7, action down
# Observation {(6, 0): np.str_('C'), (5, 0): np.str_('C')}
# New belief
# ##################
# ##    ????????p3##
# ##  ####????######
# ##    ??????????##
# ##    ##p4??????##
# ##p1  ##??##????##
# ##    ??????##??##
# ##R2##????##??Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 8, action up
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New belief
# ##################
# ##    ????????p3##
# ##  ####????######
# ##    ??????????##
# ##    ##p4??????##
# ##p1  ##??##????##
# ##Ro  ??????##??##
# ##p2##????##??Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 9, action down
# Observation {(6, 0): np.str_('C'), (5, 0): np.str_('C')}
# New belief
# ##################
# ##    ????????p3##
# ##  ####????######
# ##    ??????????##
# ##    ##p4??????##
# ##p1  ##??##????##
# ##    ??????##??##
# ##R2##????##??Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 10, action up
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New belief
# ##################
# ##    ????????p3##
# ##  ####????######
# ##    ??????????##
# ##    ##p4??????##
# ##p1  ##??##????##
# ##Ro  ??????##??##
# ##p2##????##??Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 11, action down
# Observation {(6, 0): np.str_('C'), (5, 0): np.str_('C')}
# New belief
# ##################
# ##    ????????p3##
# ##  ####????######
# ##    ??????????##
# ##    ##p4??????##
# ##p1  ##??##????##
# ##    ??????##??##
# ##R2##????##??Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 12, action up
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New belief
# ##################
# ##    ????????p3##
# ##  ####????######
# ##    ??????????##
# ##    ##p4??????##
# ##p1  ##??##????##
# ##Ro  ??????##??##
# ##p2##????##??Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 13, action down
# Observation {(6, 0): np.str_('C'), (5, 0): np.str_('C')}
# New belief
# ##################
# ##    ????????p3##
# ##  ####????######
# ##    ??????????##
# ##    ##p4??????##
# ##p1  ##??##????##
# ##    ??????##??##
# ##R2##????##??Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 14, action up
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New belief
# ##################
# ##    ????????p3##
# ##  ####????######
# ##    ??????????##
# ##    ##p4??????##
# ##p1  ##??##????##
# ##Ro  ??????##??##
# ##p2##????##??Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 15, action down
# Observation {(6, 0): np.str_('C'), (5, 0): np.str_('C')}
# New belief
# ##################
# ##    ????????p3##
# ##  ####????######
# ##    ??????????##
# ##    ##p4??????##
# ##p1  ##??##????##
# ##    ??????##??##
# ##R2##????##??Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 16, action up
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New belief
# ##################
# ##    ????????p3##
# ##  ####????######
# ##    ??????????##
# ##    ##p4??????##
# ##p1  ##??##????##
# ##Ro  ??????##??##
# ##p2##????##??Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 17, action down
# Observation {(6, 0): np.str_('C'), (5, 0): np.str_('C')}
# New belief
# ##################
# ##    ????????p3##
# ##  ####????######
# ##    ??????????##
# ##    ##p4??????##
# ##p1  ##??##????##
# ##    ??????##??##
# ##R2##????##??Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 18, action up
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New belief
# ##################
# ##    ????????p3##
# ##  ####????######
# ##    ??????????##
# ##    ##p4??????##
# ##p1  ##??##????##
# ##Ro  ??????##??##
# ##p2##????##??Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 19, action down
# Observation {(6, 0): np.str_('C'), (5, 0): np.str_('C')}
# New belief
# ##################
# ##    ????????p3##
# ##  ####????######
# ##    ??????????##
# ##    ##p4??????##
# ##p1  ##??##????##
# ##    ??????##??##
# ##R2##????##??Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 20, action up
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New belief
# ##################
# ##    ????????p3##
# ##  ####????######
# ##    ??????????##
# ##    ##p4??????##
# ##p1  ##??##????##
# ##Ro  ??????##??##
# ##p2##????##??Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 21, action down
# Observation {(6, 0): np.str_('C'), (5, 0): np.str_('C')}
# New belief
# ##################
# ##    ????????p3##
# ##  ####????######
# ##    ??????????##
# ##    ##p4???
# Final robot location (6, 0)
# Final distance (should be < initial distance) = 6

# %%
# Test 6
Grader.run_single_test_inline(TestProj1, "test_06_safe_not_smart", locals())
# Out:
# <div class="alert alert-success">
#         <strong>Test passed!!</strong>
#         </div>
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.001s
#
# OK

# %% [markdown]
# ### <a id="safe_smart"></a> 3B. Safe and smart (7 points)
#
# Let's try and make an agent that is both safe and a little smarter (although probably still a bit too conservative).
#
# We will continue to run the belief update method that you implemented above for the rest of these cases, so we only need to worry about the policy.
#
# * The first time the policy is called to generate an action, it should formulate, in PDDL, a planning problem to find a complete plan for moving people to the hospital that only traverses squares that are *known* not to have fire or walls (i.e., unknown cells are not traversable either), and returns the first step.
#
# * On subsequent calls to the policy, it should just return the next step of the plan.
#
# Just as we did in Section 1, we want you to use `pyperplan`.
#
# For reference, our solution is **15** line(s) of code.

# %%
def make_planner_policy(problem, planner):
    # Keep memory of plan and which step we're on
    status = {'plan': None, 'step': None}

    def policy(belief):
        """Returns an action string or '*Failure*' or '*Success*'."""
        # Check if goal is achieved
        if all(loc == belief.hospital for loc in belief.people.values()) and belief.carrying is None:
            return '*Success*'
        
        # If no plan, make one
        if status['plan'] is None:
            status['plan'] = planner(belief)
            status['step'] = 0
            if status['plan'] is None:
                return '*Failure*'
        
        # Return next action
        action = status['plan'][status['step']]
        status['step'] += 1
        return action
    
    # return the policy function
    return policy

# %% [markdown]
# Our safe-and-smart agent should be able to successfully rescue all 4 people and deliver them to the hospital.

# %%
def sar_policy_test():
    problem = SearchAndRescueProblem()
    base_planner = SearchAndRescuePlanner(search_algo="gbf", heuristic="hff")

    def safe_smart_planner(state):
        plan, time = base_planner.get_plan(state)
        return plan

    policy = make_planner_policy(problem, safe_smart_planner)
    state = State()
    # Observable
    bel = BeliefState(state_map=state.state_map)
    return agent_loop(problem, state, policy, bel)
sar_policy_results = sar_policy_test()
# Out:
#             <div style="margin-bottom:16px; border:1px solid #ddd; padding:8px;">
#                 <input type="range" id="41168807_7f29_4312_8db4_90a521de44e1_slider" min="0" max="110" value="0" style="width:100%">
#                 <div id="41168807_7f29_4312_8db4_90a521de44e1_label" style="font-family: sans-serif; margin-top:4px; font-size: 14px;">
#                     Render 1 of 111
#                 </div>
#                 <pre id="41168807_7f29_4312_8db4_90a521de44e1_container" style="font-family: monospace; white-space: pre; border:1px solid #ccc; padding:10px; margin-top:8px;"></pre>
#             </div>
#             <script>
#                 const states_41168807_7f29_4312_8db4_90a521de44e1 = [`Initial state
# ##################
# ##Ro          p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 0, action down
# Observation {(1, 0): np.str_('C'), (0, 0): np.str_('C'), (2, 0): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##Ro####    ######
# ##              ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 1, action down
# Observation {(2, 0): np.str_('C'), (1, 0): np.str_('C'), (3, 0): np.str_('C'), (2, 1): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##Ro            ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 2, action down
# Observation {(3, 0): np.str_('C'), (2, 0): np.str_('C'), (4, 0): np.str_('C'), (3, 1): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##Ro  ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 3, action down
# Observation {(4, 0): np.str_('C'), (3, 0): np.str_('C'), (5, 0): np.str_('C'), (4, 1): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##R1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 4, action pickup-p1
# Observation {(4, 0): np.str_('C'), (3, 0): np.str_('C'), (5, 0): np.str_('C'), (4, 1): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##Ro  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: p1
# `,`agent_loop: step 5, action down
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##Ro        ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: p1
# `,`agent_loop: step 6, action dropoff
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##R1        ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 7, action down
# Observation {(6, 0): np.str_('C'), (5, 0): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##p1        ##  ##
# ##R2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 8, action pickup-p2
# Observation {(6, 0): np.str_('C'), (5, 0): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##p1        ##  ##
# ##Ro##    ##  Ho##
# ##################
# Carrying: p2
# `,`agent_loop: step 9, action up
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##R1        ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p2
# `,`agent_loop: step 10, action right
# Observation {(5, 1): np.str_('C'), (4, 1): np.str_('C'), (5, 0): np.str_('C'), (5, 2): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##p1Ro      ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p2
# `,`agent_loop: step 11, action dropoff
# Observation {(5, 1): np.str_('C'), (4, 1): np.str_('C'), (5, 0): np.str_('C'), (5, 2): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##p1R2      ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 12, action left
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##R1p2      ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 13, action pickup-p1
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##Rop2      ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p1
# `,`agent_loop: step 14, action right
# Observation {(5, 1): np.str_('C'), (4, 1): np.str_('C'), (5, 0): np.str_('C'), (5, 2): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##  R2      ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p1
# `,`agent_loop: step 15, action right
# Observation {(5, 2): np.str_('C'), (6, 2): np.str_('C'), (5, 1): np.str_('C'), (5, 3): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##  p2Ro    ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p1
# `,`agent_loop: step 16, action dropoff
# Observation {(5, 2): np.str_('C'), (6, 2): np.str_('C'), (5, 1): np.str_('C'), (5, 3): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##  p2R1    ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 17, action left
# Observation {(5, 1): np.str_('C'), (4, 1): np.str_('C'), (5, 0): np.str_('C'), (5, 2): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##  R2p1    ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 18, action pickup-p2
# Observation {(5, 1): np.str_('C'), (4, 1): np.str_('C'), (5, 0): np.str_('C'), (5, 2): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##  Rop1    ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p2
# `,`agent_loop: step 19, action right
# Observation {(5, 2): np.str_('C'), (6, 2): np.str_('C'), (5, 1): np.str_('C'), (5, 3): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##    R1    ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p2
# `,`agent_loop: step 20, action right
# Observation {(5, 3): np.str_('C'), (4, 3): np.str_('C'), (6, 3): np.str_('C'), (5, 2): np.str_('C'), (5, 4): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##    p1Ro  ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p2
# `,`agent_loop: step 21, action dropoff
# Observation {(5, 3): np.str_('C'), (4, 3): np.str_('C'), (6, 3): np.str_('C'), (5, 2): np.str_('C'), (5, 4): np.str_('C')}
# New state
# ##################
#             <div style="margin-bottom:16px; border:1px solid #ddd; padding:8px;">
#                 <input type="range" id="5b33118d_5be8_4d10_b6df_2add73aede73_slider" min="0" max="111" value="0" style="width:100%">
#                 <div id="5b33118d_5be8_4d10_b6df_2add73aede73_label" style="font-family: sans-serif; margin-top:4px; font-size: 14px;">
#                     Render 1 of 112
#                 </div>
#                 <pre id="5b33118d_5be8_4d10_b6df_2add73aede73_container" style="font-family: monospace; white-space: pre; border:1px solid #ccc; padding:10px; margin-top:8px;"></pre>
#             </div>
#             <script>
#                 const states_5b33118d_5be8_4d10_b6df_2add73aede73 = [`Initial belief
# ##################
# ##Ro          p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`Initial observation {(0, 0): np.str_('C'), (1, 0): np.str_('C'), (0, 1): np.str_('C')}
# New belief
# ##################
# ##Ro          p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 0, action down
# Observation {(1, 0): np.str_('C'), (0, 0): np.str_('C'), (2, 0): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##Ro####    ######
# ##              ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 1, action down
# Observation {(2, 0): np.str_('C'), (1, 0): np.str_('C'), (3, 0): np.str_('C'), (2, 1): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##Ro            ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 2, action down
# Observation {(3, 0): np.str_('C'), (2, 0): np.str_('C'), (4, 0): np.str_('C'), (3, 1): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##Ro  ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 3, action down
# Observation {(4, 0): np.str_('C'), (3, 0): np.str_('C'), (5, 0): np.str_('C'), (4, 1): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##R1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 4, action pickup-p1
# Observation {(4, 0): np.str_('C'), (3, 0): np.str_('C'), (5, 0): np.str_('C'), (4, 1): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##Ro  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: p1
# `,`agent_loop: step 5, action down
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##Ro        ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: p1
# `,`agent_loop: step 6, action dropoff
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##R1        ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 7, action down
# Observation {(6, 0): np.str_('C'), (5, 0): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##p1        ##  ##
# ##R2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 8, action pickup-p2
# Observation {(6, 0): np.str_('C'), (5, 0): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##p1        ##  ##
# ##Ro##    ##  Ho##
# ##################
# Carrying: p2
# `,`agent_loop: step 9, action up
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##R1        ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p2
# `,`agent_loop: step 10, action right
# Observation {(5, 1): np.str_('C'), (4, 1): np.str_('C'), (5, 0): np.str_('C'), (5, 2): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##p1Ro      ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p2
# `,`agent_loop: step 11, action dropoff
# Observation {(5, 1): np.str_('C'), (4, 1): np.str_('C'), (5, 0): np.str_('C'), (5, 2): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##p1R2      ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 12, action left
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##R1p2      ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 13, action pickup-p1
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##Rop2      ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p1
# `,`agent_loop: step 14, action right
# Observation {(5, 1): np.str_('C'), (4, 1): np.str_('C'), (5, 0): np.str_('C'), (5, 2): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##  R2      ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p1
# `,`agent_loop: step 15, action right
# Observation {(5, 2): np.str_('C'), (6, 2): np.str_('C'), (5, 1): np.str_('C'), (5, 3): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##  p2Ro    ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p1
# `,`agent_loop: step 16, action dropoff
# Observation {(5, 2): np.str_('C'), (6, 2): np.str_('C'), (5, 1): np.str_('C'), (5, 3): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##  p2R1    ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 17, action left
# Observation {(5, 1): np.str_('C'), (4, 1): np.str_('C'), (5, 0): np.str_('C'), (5, 2): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##  R2p1    ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 18, action pickup-p2
# Observation {(5, 1): np.str_('C'), (4, 1): np.str_('C'), (5, 0): np.str_('C'), (5, 2): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##  Rop1    ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p2
# `,`agent_loop: step 19, action right
# Observation {(5, 2): np.str_('C'), (6, 2): np.str_('C'), (5, 1): np.str_('C'), (5, 3): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##    R1    ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p2
# `,`agent_loop: step 20, action right
# Observation {(5, 3): np.str_('C'), (4, 3): np.str_('C'), (6, 3): np.str_('C'), (5, 2): np.str_('C'), (5, 4): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##
# Terminate with *Success*

# %%
# Test 7
Grader.run_single_test_inline(TestProj1, "test_07_safe_smart", locals())
# Out:
# <div class="alert alert-success">
#         <strong>Test passed!!</strong>
#         </div>
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.002s
#
# OK

# %% [markdown]
# ### <a id="reckless"></a> 3C. Reckless (7 points)
#
# For this and the remaining questions, we're not going to autograde your solutions, and we're not providing test cases. We've given you boxes to hold your implementation, but you will need to define your own tests cases, and in section 4, we'll ask you to do some analysis.
#
# First, let's try to make our agent more aggressive but still not step into the fire!   As we saw in 3.1, even if we make a plan that might cause us to move into the fire, just before we are about to take an action, we can know for sure whether there is fire in the square we are about to move into.   So, let's make an (almost) reckless replanning agent.
#
# * The first time the policy is called to generate an action, it should formulate in PDDL a planning problem to find a very optimistic  plan for moving people to the hospital that only traverses squares that are **not known to have** fire or walls (i.e., unknowns are fair game), and returns the first step.
#
# * On subsequent calls to the policy, if the next step in the plan is safe to execute given the updated belief, it should return that action.  Otherwise, it should make a new plan!

# %%
def make_reckless_policy(problem, planner):
    # Keep memory of plan and which step we're on
    status = {'plan': None, 'step': None}

    def policy(belief):
        """Returns an action string or '*Failure*' or '*Success*'."""
        # Check if goal is achieved
        if all(loc == belief.hospital for loc in belief.people.values()) and belief.carrying is None:
            return '*Success*'
        
        # If no plan or next action is unsafe, replan
        if status['plan'] is None or (status['step'] < len(status['plan']) and not is_action_safe(belief, status['plan'][status['step']], problem)):
            optimistic_state = belief.get_optimistic_state()
            status['plan'] = planner(optimistic_state)
            status['step'] = 0
            if status['plan'] is None:
                return '*Failure*'
        
        # Return next action
        action = status['plan'][status['step']]
        status['step'] += 1
        return action
    
    # return the policy function
    return policy

def is_action_safe(belief, action, problem):
    """Check if an action is safe to execute given current belief."""
    if action in ['up', 'down', 'left', 'right']:
        dr, dc = problem.action_deltas[action]
        r, c = belief.robot
        new_r, new_c = r + dr, c + dc
        safe_grid = belief.get_safe_grid()
        return (0 <= new_r < safe_grid.shape[0] and 
                0 <= new_c < safe_grid.shape[1] and 
                safe_grid[new_r, new_c])
    return True

# %% [markdown]
# Use the code below to run your policy and provide an execution trace.

# %%
def reckless_policy_test():
    problem = SearchAndRescueProblem()
    base_planner = SearchAndRescuePlanner(search_algo="gbf", heuristic="hff")

    def reckless_planner(state):
        plan, time = base_planner.get_plan(state)
        return plan

    policy = make_reckless_policy(problem, reckless_planner)
    state = State()
    # Observable
    bel = BeliefState(state_map=state.state_map)
    s_or_f, final_state, final_bel = agent_loop(problem, state, policy, bel)
reckless_policy_test()
# Out:
#             <div style="margin-bottom:16px; border:1px solid #ddd; padding:8px;">
#                 <input type="range" id="ff62d315_6724_4956_8add_b28a077b61e5_slider" min="0" max="110" value="0" style="width:100%">
#                 <div id="ff62d315_6724_4956_8add_b28a077b61e5_label" style="font-family: sans-serif; margin-top:4px; font-size: 14px;">
#                     Render 1 of 111
#                 </div>
#                 <pre id="ff62d315_6724_4956_8add_b28a077b61e5_container" style="font-family: monospace; white-space: pre; border:1px solid #ccc; padding:10px; margin-top:8px;"></pre>
#             </div>
#             <script>
#                 const states_ff62d315_6724_4956_8add_b28a077b61e5 = [`Initial state
# ##################
# ##Ro          p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 0, action down
# Observation {(1, 0): np.str_('C'), (0, 0): np.str_('C'), (2, 0): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##Ro####    ######
# ##              ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 1, action down
# Observation {(2, 0): np.str_('C'), (1, 0): np.str_('C'), (3, 0): np.str_('C'), (2, 1): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##Ro            ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 2, action down
# Observation {(3, 0): np.str_('C'), (2, 0): np.str_('C'), (4, 0): np.str_('C'), (3, 1): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##Ro  ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 3, action down
# Observation {(4, 0): np.str_('C'), (3, 0): np.str_('C'), (5, 0): np.str_('C'), (4, 1): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##R1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 4, action pickup-p1
# Observation {(4, 0): np.str_('C'), (3, 0): np.str_('C'), (5, 0): np.str_('C'), (4, 1): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##Ro  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: p1
# `,`agent_loop: step 5, action down
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##Ro        ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: p1
# `,`agent_loop: step 6, action dropoff
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##R1        ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 7, action down
# Observation {(6, 0): np.str_('C'), (5, 0): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##p1        ##  ##
# ##R2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 8, action pickup-p2
# Observation {(6, 0): np.str_('C'), (5, 0): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##p1        ##  ##
# ##Ro##    ##  Ho##
# ##################
# Carrying: p2
# `,`agent_loop: step 9, action up
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##R1        ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p2
# `,`agent_loop: step 10, action right
# Observation {(5, 1): np.str_('C'), (4, 1): np.str_('C'), (5, 0): np.str_('C'), (5, 2): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##p1Ro      ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p2
# `,`agent_loop: step 11, action dropoff
# Observation {(5, 1): np.str_('C'), (4, 1): np.str_('C'), (5, 0): np.str_('C'), (5, 2): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##p1R2      ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 12, action left
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##R1p2      ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 13, action pickup-p1
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##Rop2      ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p1
# `,`agent_loop: step 14, action right
# Observation {(5, 1): np.str_('C'), (4, 1): np.str_('C'), (5, 0): np.str_('C'), (5, 2): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##  R2      ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p1
# `,`agent_loop: step 15, action right
# Observation {(5, 2): np.str_('C'), (6, 2): np.str_('C'), (5, 1): np.str_('C'), (5, 3): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##  p2Ro    ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p1
# `,`agent_loop: step 16, action dropoff
# Observation {(5, 2): np.str_('C'), (6, 2): np.str_('C'), (5, 1): np.str_('C'), (5, 3): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##  p2R1    ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 17, action left
# Observation {(5, 1): np.str_('C'), (4, 1): np.str_('C'), (5, 0): np.str_('C'), (5, 2): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##  R2p1    ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 18, action pickup-p2
# Observation {(5, 1): np.str_('C'), (4, 1): np.str_('C'), (5, 0): np.str_('C'), (5, 2): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##  Rop1    ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p2
# `,`agent_loop: step 19, action right
# Observation {(5, 2): np.str_('C'), (6, 2): np.str_('C'), (5, 1): np.str_('C'), (5, 3): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##    R1    ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p2
# `,`agent_loop: step 20, action right
# Observation {(5, 3): np.str_('C'), (4, 3): np.str_('C'), (6, 3): np.str_('C'), (5, 2): np.str_('C'), (5, 4): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##    p1Ro  ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p2
# `,`agent_loop: step 21, action dropoff
# Observation {(5, 3): np.str_('C'), (4, 3): np.str_('C'), (6, 3): np.str_('C'), (5, 2): np.str_('C'), (5, 4): np.str_('C')}
# New state
# ##################
#             <div style="margin-bottom:16px; border:1px solid #ddd; padding:8px;">
#                 <input type="range" id="787bbc15_34a9_4e16_8e9d_244390cd10b4_slider" min="0" max="111" value="0" style="width:100%">
#                 <div id="787bbc15_34a9_4e16_8e9d_244390cd10b4_label" style="font-family: sans-serif; margin-top:4px; font-size: 14px;">
#                     Render 1 of 112
#                 </div>
#                 <pre id="787bbc15_34a9_4e16_8e9d_244390cd10b4_container" style="font-family: monospace; white-space: pre; border:1px solid #ccc; padding:10px; margin-top:8px;"></pre>
#             </div>
#             <script>
#                 const states_787bbc15_34a9_4e16_8e9d_244390cd10b4 = [`Initial belief
# ##################
# ##Ro          p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`Initial observation {(0, 0): np.str_('C'), (1, 0): np.str_('C'), (0, 1): np.str_('C')}
# New belief
# ##################
# ##Ro          p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 0, action down
# Observation {(1, 0): np.str_('C'), (0, 0): np.str_('C'), (2, 0): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##Ro####    ######
# ##              ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 1, action down
# Observation {(2, 0): np.str_('C'), (1, 0): np.str_('C'), (3, 0): np.str_('C'), (2, 1): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##Ro            ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 2, action down
# Observation {(3, 0): np.str_('C'), (2, 0): np.str_('C'), (4, 0): np.str_('C'), (3, 1): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##Ro  ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 3, action down
# Observation {(4, 0): np.str_('C'), (3, 0): np.str_('C'), (5, 0): np.str_('C'), (4, 1): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##R1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 4, action pickup-p1
# Observation {(4, 0): np.str_('C'), (3, 0): np.str_('C'), (5, 0): np.str_('C'), (4, 1): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##Ro  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: p1
# `,`agent_loop: step 5, action down
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##Ro        ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: p1
# `,`agent_loop: step 6, action dropoff
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##R1        ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 7, action down
# Observation {(6, 0): np.str_('C'), (5, 0): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##p1        ##  ##
# ##R2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 8, action pickup-p2
# Observation {(6, 0): np.str_('C'), (5, 0): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##p1        ##  ##
# ##Ro##    ##  Ho##
# ##################
# Carrying: p2
# `,`agent_loop: step 9, action up
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##R1        ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p2
# `,`agent_loop: step 10, action right
# Observation {(5, 1): np.str_('C'), (4, 1): np.str_('C'), (5, 0): np.str_('C'), (5, 2): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##p1Ro      ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p2
# `,`agent_loop: step 11, action dropoff
# Observation {(5, 1): np.str_('C'), (4, 1): np.str_('C'), (5, 0): np.str_('C'), (5, 2): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##p1R2      ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 12, action left
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##R1p2      ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 13, action pickup-p1
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##Rop2      ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p1
# `,`agent_loop: step 14, action right
# Observation {(5, 1): np.str_('C'), (4, 1): np.str_('C'), (5, 0): np.str_('C'), (5, 2): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##  R2      ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p1
# `,`agent_loop: step 15, action right
# Observation {(5, 2): np.str_('C'), (6, 2): np.str_('C'), (5, 1): np.str_('C'), (5, 3): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##  p2Ro    ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p1
# `,`agent_loop: step 16, action dropoff
# Observation {(5, 2): np.str_('C'), (6, 2): np.str_('C'), (5, 1): np.str_('C'), (5, 3): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##  p2R1    ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 17, action left
# Observation {(5, 1): np.str_('C'), (4, 1): np.str_('C'), (5, 0): np.str_('C'), (5, 2): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##  R2p1    ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 18, action pickup-p2
# Observation {(5, 1): np.str_('C'), (4, 1): np.str_('C'), (5, 0): np.str_('C'), (5, 2): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##  Rop1    ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p2
# `,`agent_loop: step 19, action right
# Observation {(5, 2): np.str_('C'), (6, 2): np.str_('C'), (5, 1): np.str_('C'), (5, 3): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##    R1    ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p2
# `,`agent_loop: step 20, action right
# Observation {(5, 3): np.str_('C'), (4, 3): np.str_('C'), (6, 3): np.str_('C'), (5, 2): np.str_('C'), (5, 4): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##
# Terminate with *Success*

# %% [markdown]
# ### <a id="safe_smart_reckless"></a> 3D. Safe and smart if possible, else reckless (7 points)
#
# Try to construct a new policy that is a useful combination of "safe and smart" and "reckless" strategies, which combines the best aspects of each.

# %%
def make_hybrid_policy(problem, planner):
    # Keep memory of plan and which step we're on
    status = {'plan': None, 'step': None, 'mode': 'safe'}

    def policy(belief):
        """Returns an action string or '*Failure*' or '*Success*'."""
        # Check if goal is achieved
        if all(loc == belief.hospital for loc in belief.people.values()) and belief.carrying is None:
            return '*Success*'
        
        # Try safe planning first
        if status['plan'] is None:
            careful_state = belief.get_careful_state()
            status['plan'] = planner(careful_state)
            if status['plan'] is not None:
                status['mode'] = 'safe'
                status['step'] = 0
            else:
                # If safe planning fails, try reckless
                optimistic_state = belief.get_optimistic_state()
                status['plan'] = planner(optimistic_state)
                status['mode'] = 'reckless'
                status['step'] = 0
                if status['plan'] is None:
                    return '*Failure*'
        
        # In reckless mode, check if next action is safe and replan if not
        if status['mode'] == 'reckless' and status['step'] < len(status['plan']):
            if not is_action_safe(belief, status['plan'][status['step']], problem):
                optimistic_state = belief.get_optimistic_state()
                status['plan'] = planner(optimistic_state)
                status['step'] = 0
                if status['plan'] is None:
                    return '*Failure*'
        
        # Return next action
        action = status['plan'][status['step']]
        status['step'] += 1
        return action
    
    # return the policy function
    return policy

# %% [markdown]
# Use the code below to run your policy and provide an execution trace.

# %%
def hybrid_policy_test():
    problem = SearchAndRescueProblem()
    base_planner = SearchAndRescuePlanner(search_algo="gbf", heuristic="hff")

    def hybrid_planner(state):
        plan, time = base_planner.get_plan(state)
        return plan

    policy = make_hybrid_policy(problem, hybrid_planner)
    state = State()
    # Observable
    bel = BeliefState(state_map=state.state_map)
    s_or_f, final_state, final_bel = agent_loop(problem, state, policy, bel)
hybrid_policy_test()
# Out:
#             <div style="margin-bottom:16px; border:1px solid #ddd; padding:8px;">
#                 <input type="range" id="b6d5410e_550a_4a5e_a495_533c35ab178b_slider" min="0" max="110" value="0" style="width:100%">
#                 <div id="b6d5410e_550a_4a5e_a495_533c35ab178b_label" style="font-family: sans-serif; margin-top:4px; font-size: 14px;">
#                     Render 1 of 111
#                 </div>
#                 <pre id="b6d5410e_550a_4a5e_a495_533c35ab178b_container" style="font-family: monospace; white-space: pre; border:1px solid #ccc; padding:10px; margin-top:8px;"></pre>
#             </div>
#             <script>
#                 const states_b6d5410e_550a_4a5e_a495_533c35ab178b = [`Initial state
# ##################
# ##Ro          p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 0, action down
# Observation {(1, 0): np.str_('C'), (0, 0): np.str_('C'), (2, 0): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##Ro####    ######
# ##              ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 1, action down
# Observation {(2, 0): np.str_('C'), (1, 0): np.str_('C'), (3, 0): np.str_('C'), (2, 1): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##Ro            ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 2, action down
# Observation {(3, 0): np.str_('C'), (2, 0): np.str_('C'), (4, 0): np.str_('C'), (3, 1): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##Ro  ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 3, action down
# Observation {(4, 0): np.str_('C'), (3, 0): np.str_('C'), (5, 0): np.str_('C'), (4, 1): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##R1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 4, action pickup-p1
# Observation {(4, 0): np.str_('C'), (3, 0): np.str_('C'), (5, 0): np.str_('C'), (4, 1): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##Ro  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: p1
# `,`agent_loop: step 5, action down
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##Ro        ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: p1
# `,`agent_loop: step 6, action dropoff
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##R1        ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 7, action down
# Observation {(6, 0): np.str_('C'), (5, 0): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##p1        ##  ##
# ##R2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 8, action pickup-p2
# Observation {(6, 0): np.str_('C'), (5, 0): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##p1        ##  ##
# ##Ro##    ##  Ho##
# ##################
# Carrying: p2
# `,`agent_loop: step 9, action up
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##R1        ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p2
# `,`agent_loop: step 10, action right
# Observation {(5, 1): np.str_('C'), (4, 1): np.str_('C'), (5, 0): np.str_('C'), (5, 2): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##p1Ro      ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p2
# `,`agent_loop: step 11, action dropoff
# Observation {(5, 1): np.str_('C'), (4, 1): np.str_('C'), (5, 0): np.str_('C'), (5, 2): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##p1R2      ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 12, action left
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##R1p2      ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 13, action pickup-p1
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##Rop2      ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p1
# `,`agent_loop: step 14, action right
# Observation {(5, 1): np.str_('C'), (4, 1): np.str_('C'), (5, 0): np.str_('C'), (5, 2): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##  R2      ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p1
# `,`agent_loop: step 15, action right
# Observation {(5, 2): np.str_('C'), (6, 2): np.str_('C'), (5, 1): np.str_('C'), (5, 3): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##  p2Ro    ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p1
# `,`agent_loop: step 16, action dropoff
# Observation {(5, 2): np.str_('C'), (6, 2): np.str_('C'), (5, 1): np.str_('C'), (5, 3): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##  p2R1    ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 17, action left
# Observation {(5, 1): np.str_('C'), (4, 1): np.str_('C'), (5, 0): np.str_('C'), (5, 2): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##  R2p1    ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 18, action pickup-p2
# Observation {(5, 1): np.str_('C'), (4, 1): np.str_('C'), (5, 0): np.str_('C'), (5, 2): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##  Rop1    ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p2
# `,`agent_loop: step 19, action right
# Observation {(5, 2): np.str_('C'), (6, 2): np.str_('C'), (5, 1): np.str_('C'), (5, 3): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##    R1    ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p2
# `,`agent_loop: step 20, action right
# Observation {(5, 3): np.str_('C'), (4, 3): np.str_('C'), (6, 3): np.str_('C'), (5, 2): np.str_('C'), (5, 4): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##    p1Ro  ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p2
# `,`agent_loop: step 21, action dropoff
# Observation {(5, 3): np.str_('C'), (4, 3): np.str_('C'), (6, 3): np.str_('C'), (5, 2): np.str_('C'), (5, 4): np.str_('C')}
# New state
# ##################
#             <div style="margin-bottom:16px; border:1px solid #ddd; padding:8px;">
#                 <input type="range" id="e5c0ec4e_0261_4894_a6ad_70d094f7b9dc_slider" min="0" max="111" value="0" style="width:100%">
#                 <div id="e5c0ec4e_0261_4894_a6ad_70d094f7b9dc_label" style="font-family: sans-serif; margin-top:4px; font-size: 14px;">
#                     Render 1 of 112
#                 </div>
#                 <pre id="e5c0ec4e_0261_4894_a6ad_70d094f7b9dc_container" style="font-family: monospace; white-space: pre; border:1px solid #ccc; padding:10px; margin-top:8px;"></pre>
#             </div>
#             <script>
#                 const states_e5c0ec4e_0261_4894_a6ad_70d094f7b9dc = [`Initial belief
# ##################
# ##Ro          p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`Initial observation {(0, 0): np.str_('C'), (1, 0): np.str_('C'), (0, 1): np.str_('C')}
# New belief
# ##################
# ##Ro          p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 0, action down
# Observation {(1, 0): np.str_('C'), (0, 0): np.str_('C'), (2, 0): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##Ro####    ######
# ##              ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 1, action down
# Observation {(2, 0): np.str_('C'), (1, 0): np.str_('C'), (3, 0): np.str_('C'), (2, 1): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##Ro            ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 2, action down
# Observation {(3, 0): np.str_('C'), (2, 0): np.str_('C'), (4, 0): np.str_('C'), (3, 1): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##Ro  ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 3, action down
# Observation {(4, 0): np.str_('C'), (3, 0): np.str_('C'), (5, 0): np.str_('C'), (4, 1): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##R1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 4, action pickup-p1
# Observation {(4, 0): np.str_('C'), (3, 0): np.str_('C'), (5, 0): np.str_('C'), (4, 1): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##Ro  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: p1
# `,`agent_loop: step 5, action down
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##Ro        ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: p1
# `,`agent_loop: step 6, action dropoff
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##R1        ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 7, action down
# Observation {(6, 0): np.str_('C'), (5, 0): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##p1        ##  ##
# ##R2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 8, action pickup-p2
# Observation {(6, 0): np.str_('C'), (5, 0): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##p1        ##  ##
# ##Ro##    ##  Ho##
# ##################
# Carrying: p2
# `,`agent_loop: step 9, action up
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##R1        ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p2
# `,`agent_loop: step 10, action right
# Observation {(5, 1): np.str_('C'), (4, 1): np.str_('C'), (5, 0): np.str_('C'), (5, 2): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##p1Ro      ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p2
# `,`agent_loop: step 11, action dropoff
# Observation {(5, 1): np.str_('C'), (4, 1): np.str_('C'), (5, 0): np.str_('C'), (5, 2): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##p1R2      ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 12, action left
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##R1p2      ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 13, action pickup-p1
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##Rop2      ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p1
# `,`agent_loop: step 14, action right
# Observation {(5, 1): np.str_('C'), (4, 1): np.str_('C'), (5, 0): np.str_('C'), (5, 2): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##  R2      ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p1
# `,`agent_loop: step 15, action right
# Observation {(5, 2): np.str_('C'), (6, 2): np.str_('C'), (5, 1): np.str_('C'), (5, 3): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##  p2Ro    ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p1
# `,`agent_loop: step 16, action dropoff
# Observation {(5, 2): np.str_('C'), (6, 2): np.str_('C'), (5, 1): np.str_('C'), (5, 3): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##  p2R1    ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 17, action left
# Observation {(5, 1): np.str_('C'), (4, 1): np.str_('C'), (5, 0): np.str_('C'), (5, 2): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##  R2p1    ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 18, action pickup-p2
# Observation {(5, 1): np.str_('C'), (4, 1): np.str_('C'), (5, 0): np.str_('C'), (5, 2): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##  Rop1    ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p2
# `,`agent_loop: step 19, action right
# Observation {(5, 2): np.str_('C'), (6, 2): np.str_('C'), (5, 1): np.str_('C'), (5, 3): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##    R1    ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p2
# `,`agent_loop: step 20, action right
# Observation {(5, 3): np.str_('C'), (4, 3): np.str_('C'), (6, 3): np.str_('C'), (5, 2): np.str_('C'), (5, 4): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##
# Terminate with *Success*

# %% [markdown]
# ### <a id="look_before"></a> 3E. Looks before it leaps (7 points)
#
# Another way to approach this problem is to plan in belief space.  That sounds fancy, but actually can be relatively simple to do:
#
# * In your PDDL formulation, instead of just having a fluent `(is-clear ?loc)`, we'll have two fluents:  `(is-clear ?loc)` and `(is-unknown ?loc)`.
#
# * The precondition for moving into a square should still be `(is-clear ?loc)`.
#
# * You can add an operator that explicitly "looks" at a neighboring square;  we'll assume that it's optimistic and so if you look at a square that was previously unknown, it is now known to be clear.
#
# * Note that you can define a [subclass](https://www.geeksforgeeks.org/python/create-a-python-subclass/) of `SearchAndRescuePlanner` and redefine the `update_pddl_domain` method to add to the previous PDDL domain definition.  You'll also need to change the `parse_plan` method to handle the new action and the `get_init_strs` method to handle the new facts.
#
# * Make a replanning policy that plans in this belief-space formulation and executes its plan as long as it's safe, and replans otherwise.

# %%
class BeliefSpacePlanner(SearchAndRescuePlanner):
    def update_pddl_domain(self):
        domain_name = 'searchandrescue_belief'
        added_predicate = '(is-unknown ?v0 - location)'
        added_operator = """
  (:action look
    :parameters (?loc - location)
    :precondition (and
      (is-unknown ?loc)
    )
    :effect (and
      (not (is-unknown ?loc))
      (is-clear ?loc)
    )
  )"""
        return domain_name, added_predicate, added_operator
    
    def get_init_strs(self, state):
        height, width = state.state_map.shape
        robot_r, robot_c = state.robot
        init_strs = [f"(robot-at l{robot_r}-{robot_c})"]
        for person, (r, c) in state.people.items():
            init_strs.append(f"(person-at {person} l{r}-{c})")
        if state.carrying is not None:
            init_strs.append(f"(carrying {state.carrying})")
        else:
            init_strs.append("(handsfree)")
            
        deltas = {
            "up": (-1, 0),
            "down": (1, 0),
            "left": (0, -1),
            "right": (0, 1),
        }
        
        for r in range(height):
            for c in range(width):
                for direction, (dr, dc) in deltas.items():
                    if not (0 <= r + dr < height and 0 <= c + dc < width):
                        continue
                    init_strs.append(
                        f"(conn l{r}-{c} l{r + dr}-{c + dc} {direction})")
                
                if state.state_map[r, c] == 'C' or state.state_map[r, c] == 'S':
                    init_strs.append(f"(is-clear l{r}-{c})")
                elif state.state_map[r, c] == 'U':
                    init_strs.append(f"(is-unknown l{r}-{c})")

        init_str = " ".join(init_strs)
        return init_str
    
    def parse_plan(self, plan):
        actions = []
        for op in plan:
            if "move-robot" in op.name:
                _, direction = op.name[:-1].rsplit(" ", 1)
                action = direction
            elif "pickup-person" in op.name:
                _, person, _ = op.name.split(" ")
                action = f"pickup-{person}"
            elif "dropoff-person" in op.name:
                action = "dropoff"
            elif "look" in op.name:
                _, loc = op.name.split(" ")
                action = f"look-{loc}"
            else:
                continue
            actions.append(action)
        return actions

def make_belief_space_policy(problem, planner):
    # Keep memory of plan and which step we're on
    status = {'plan': None, 'step': None}

    def policy(belief):
        """Returns an action string or '*Failure*' or '*Success*'."""
        # Check if goal is achieved
        if all(loc == belief.hospital for loc in belief.people.values()) and belief.carrying is None:
            return '*Success*'
        
        # If no plan or next action is unsafe, replan
        if status['plan'] is None or (status['step'] < len(status['plan']) and not is_action_safe(belief, status['plan'][status['step']], problem)):
            bs_planner = BeliefSpacePlanner(search_algo="gbf", heuristic="hff")
            status['plan'], _ = bs_planner.get_plan(belief)
            status['step'] = 0
            if status['plan'] is None:
                return '*Failure*'
        
        # Return next action (skip look actions)
        action = status['plan'][status['step']]
        status['step'] += 1
        
        # Skip look actions as they don't affect state
        while action.startswith('look'):
            if status['step'] >= len(status['plan']):
                break
            action = status['plan'][status['step']]
            status['step'] += 1
        
        return action
    
    # return the policy function
    return policy

# %% [markdown]
# Use the code below to run your policy and provide an execution trace.

# %%
def belief_space_policy_test():
    problem = SearchAndRescueProblem()
    base_planner = SearchAndRescuePlanner(search_algo="gbf", heuristic="hff")

    def belief_space_planner(state):
        plan, time = base_planner.get_plan(state)
        return plan

    policy = make_belief_space_policy(problem, belief_space_planner)
    state = State()
    # Observable
    bel = BeliefState(state_map=state.state_map)
    s_or_f, final_state, final_bel = agent_loop(problem, state, policy, bel)
belief_space_policy_test()
# Out:
#             <div style="margin-bottom:16px; border:1px solid #ddd; padding:8px;">
#                 <input type="range" id="e77d2ee5_8bde_4cff_9a09_eb148944aacf_slider" min="0" max="110" value="0" style="width:100%">
#                 <div id="e77d2ee5_8bde_4cff_9a09_eb148944aacf_label" style="font-family: sans-serif; margin-top:4px; font-size: 14px;">
#                     Render 1 of 111
#                 </div>
#                 <pre id="e77d2ee5_8bde_4cff_9a09_eb148944aacf_container" style="font-family: monospace; white-space: pre; border:1px solid #ccc; padding:10px; margin-top:8px;"></pre>
#             </div>
#             <script>
#                 const states_e77d2ee5_8bde_4cff_9a09_eb148944aacf = [`Initial state
# ##################
# ##Ro          p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 0, action down
# Observation {(1, 0): np.str_('C'), (0, 0): np.str_('C'), (2, 0): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##Ro####    ######
# ##              ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 1, action down
# Observation {(2, 0): np.str_('C'), (1, 0): np.str_('C'), (3, 0): np.str_('C'), (2, 1): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##Ro            ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 2, action down
# Observation {(3, 0): np.str_('C'), (2, 0): np.str_('C'), (4, 0): np.str_('C'), (3, 1): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##Ro  ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 3, action down
# Observation {(4, 0): np.str_('C'), (3, 0): np.str_('C'), (5, 0): np.str_('C'), (4, 1): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##R1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 4, action pickup-p1
# Observation {(4, 0): np.str_('C'), (3, 0): np.str_('C'), (5, 0): np.str_('C'), (4, 1): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##Ro  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: p1
# `,`agent_loop: step 5, action down
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##Ro        ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: p1
# `,`agent_loop: step 6, action dropoff
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##R1        ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 7, action down
# Observation {(6, 0): np.str_('C'), (5, 0): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##p1        ##  ##
# ##R2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 8, action pickup-p2
# Observation {(6, 0): np.str_('C'), (5, 0): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##p1        ##  ##
# ##Ro##    ##  Ho##
# ##################
# Carrying: p2
# `,`agent_loop: step 9, action up
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##R1        ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p2
# `,`agent_loop: step 10, action right
# Observation {(5, 1): np.str_('C'), (4, 1): np.str_('C'), (5, 0): np.str_('C'), (5, 2): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##p1Ro      ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p2
# `,`agent_loop: step 11, action dropoff
# Observation {(5, 1): np.str_('C'), (4, 1): np.str_('C'), (5, 0): np.str_('C'), (5, 2): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##p1R2      ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 12, action left
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##R1p2      ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 13, action pickup-p1
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##Rop2      ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p1
# `,`agent_loop: step 14, action right
# Observation {(5, 1): np.str_('C'), (4, 1): np.str_('C'), (5, 0): np.str_('C'), (5, 2): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##  R2      ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p1
# `,`agent_loop: step 15, action right
# Observation {(5, 2): np.str_('C'), (6, 2): np.str_('C'), (5, 1): np.str_('C'), (5, 3): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##  p2Ro    ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p1
# `,`agent_loop: step 16, action dropoff
# Observation {(5, 2): np.str_('C'), (6, 2): np.str_('C'), (5, 1): np.str_('C'), (5, 3): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##  p2R1    ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 17, action left
# Observation {(5, 1): np.str_('C'), (4, 1): np.str_('C'), (5, 0): np.str_('C'), (5, 2): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##  R2p1    ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 18, action pickup-p2
# Observation {(5, 1): np.str_('C'), (4, 1): np.str_('C'), (5, 0): np.str_('C'), (5, 2): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##  Rop1    ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p2
# `,`agent_loop: step 19, action right
# Observation {(5, 2): np.str_('C'), (6, 2): np.str_('C'), (5, 1): np.str_('C'), (5, 3): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##    R1    ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p2
# `,`agent_loop: step 20, action right
# Observation {(5, 3): np.str_('C'), (4, 3): np.str_('C'), (6, 3): np.str_('C'), (5, 2): np.str_('C'), (5, 4): np.str_('C')}
# New state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##    p1Ro  ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p2
# `,`agent_loop: step 21, action dropoff
# Observation {(5, 3): np.str_('C'), (4, 3): np.str_('C'), (6, 3): np.str_('C'), (5, 2): np.str_('C'), (5, 4): np.str_('C')}
# New state
# ##################
#             <div style="margin-bottom:16px; border:1px solid #ddd; padding:8px;">
#                 <input type="range" id="d06e3800_9160_4689_89e3_14ec2c29a076_slider" min="0" max="111" value="0" style="width:100%">
#                 <div id="d06e3800_9160_4689_89e3_14ec2c29a076_label" style="font-family: sans-serif; margin-top:4px; font-size: 14px;">
#                     Render 1 of 112
#                 </div>
#                 <pre id="d06e3800_9160_4689_89e3_14ec2c29a076_container" style="font-family: monospace; white-space: pre; border:1px solid #ccc; padding:10px; margin-top:8px;"></pre>
#             </div>
#             <script>
#                 const states_d06e3800_9160_4689_89e3_14ec2c29a076 = [`Initial belief
# ##################
# ##Ro          p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`Initial observation {(0, 0): np.str_('C'), (1, 0): np.str_('C'), (0, 1): np.str_('C')}
# New belief
# ##################
# ##Ro          p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 0, action down
# Observation {(1, 0): np.str_('C'), (0, 0): np.str_('C'), (2, 0): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##Ro####    ######
# ##              ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 1, action down
# Observation {(2, 0): np.str_('C'), (1, 0): np.str_('C'), (3, 0): np.str_('C'), (2, 1): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##Ro            ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 2, action down
# Observation {(3, 0): np.str_('C'), (2, 0): np.str_('C'), (4, 0): np.str_('C'), (3, 1): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##Ro  ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 3, action down
# Observation {(4, 0): np.str_('C'), (3, 0): np.str_('C'), (5, 0): np.str_('C'), (4, 1): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##R1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 4, action pickup-p1
# Observation {(4, 0): np.str_('C'), (3, 0): np.str_('C'), (5, 0): np.str_('C'), (4, 1): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##Ro  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: p1
# `,`agent_loop: step 5, action down
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##Ro        ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: p1
# `,`agent_loop: step 6, action dropoff
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##R1        ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 7, action down
# Observation {(6, 0): np.str_('C'), (5, 0): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##p1        ##  ##
# ##R2##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 8, action pickup-p2
# Observation {(6, 0): np.str_('C'), (5, 0): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##p1        ##  ##
# ##Ro##    ##  Ho##
# ##################
# Carrying: p2
# `,`agent_loop: step 9, action up
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##R1        ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p2
# `,`agent_loop: step 10, action right
# Observation {(5, 1): np.str_('C'), (4, 1): np.str_('C'), (5, 0): np.str_('C'), (5, 2): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##p1Ro      ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p2
# `,`agent_loop: step 11, action dropoff
# Observation {(5, 1): np.str_('C'), (4, 1): np.str_('C'), (5, 0): np.str_('C'), (5, 2): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##p1R2      ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 12, action left
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##R1p2      ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 13, action pickup-p1
# Observation {(5, 0): np.str_('C'), (4, 0): np.str_('C'), (6, 0): np.str_('C'), (5, 1): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##Rop2      ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p1
# `,`agent_loop: step 14, action right
# Observation {(5, 1): np.str_('C'), (4, 1): np.str_('C'), (5, 0): np.str_('C'), (5, 2): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##  R2      ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p1
# `,`agent_loop: step 15, action right
# Observation {(5, 2): np.str_('C'), (6, 2): np.str_('C'), (5, 1): np.str_('C'), (5, 3): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##  p2Ro    ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p1
# `,`agent_loop: step 16, action dropoff
# Observation {(5, 2): np.str_('C'), (6, 2): np.str_('C'), (5, 1): np.str_('C'), (5, 3): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##  p2R1    ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 17, action left
# Observation {(5, 1): np.str_('C'), (4, 1): np.str_('C'), (5, 0): np.str_('C'), (5, 2): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##  R2p1    ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: None
# `,`agent_loop: step 18, action pickup-p2
# Observation {(5, 1): np.str_('C'), (4, 1): np.str_('C'), (5, 0): np.str_('C'), (5, 2): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##  Rop1    ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p2
# `,`agent_loop: step 19, action right
# Observation {(5, 2): np.str_('C'), (6, 2): np.str_('C'), (5, 1): np.str_('C'), (5, 3): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##    R1    ##  ##
# ##  ##    ##  Ho##
# ##################
# Carrying: p2
# `,`agent_loop: step 20, action right
# Observation {(5, 3): np.str_('C'), (4, 3): np.str_('C'), (6, 3): np.str_('C'), (5, 2): np.str_('C'), (5, 4): np.str_('C')}
# New belief
# ##################
# ##            p3##
# ##  ####    ######
# ##
# Terminate with *Success*

# %% [markdown]
# ## <a id="analysis"></a> 4. Analysis (30 points)
#
# In the following questions, please provide textual answers in the provided boxes.

# %% [markdown]
# **First-order Logic:** In what way would having access to first-order logic have been helpful in this problem?
#
# <div class="alert alert-info">
# Write your answer in the cell below this one.
# </div>

# %% [markdown]
# First order logic would let us write the rules once with quantifiers instead of grounding everything per cell. For example, “every smoke cell must have a neighboring fire” could be a single quantified rule over all locations, rather than a huge set of propositional clauses. That cuts domain size, reduces duplication, and makes the model easier to maintain for larger grids.han instantiating connections for every cell pair.

# %% [markdown]
# **Heuristics:** The heuristics used in `pyperplan` are *domain-independent*; we can use them for Search and Rescue, for blocks world, etc.  An alternative strategy would be to hand-specify a *domain-specific* heuristic. What would a good domain-specific heuristic for search and rescue look like?
#
# <div class="alert alert-info">
# Write your answer in the cell below this one.
# </div>

# %% [markdown]
# Domain specific heuristic:
#
# Measure shortest-path steps on the safe grid (avoid walls/fire; treat unknowns as blocked for “safe,” or as clear for “reckless”).
#
# If not carrying: pick the person that gives the smallest total trip (robot -> person -> hospital), then add the trips from all other people to the hospital.
#
# If carrying: prioritize going straight to the hospital, then add the trips from remaining people to the hospital.
#
# Add tiny penalties for routes that hug fire; break ties by preferring states with more safe options ahead.
#
# Compute distances with BFS/Dijkstra for speed and obstacle awareness.

# %% [markdown]
# **Look first:** We do one observation before choosing our first action.  Give an example scenario where omitting this step and using the reckless or two-phase planner would make an error.
#
# <div class="alert alert-info">
# Write your answer in the cell below this one.
# </div>

# %% [markdown]
# If the robot starts at (0,0) and there is fire at (0,1) and (1,0), without the initial observation, a reckless planner would assume these cells are clear and plan to move right or down. When attempting to execute the first action, it would try to move into fire. With the initial observation, the robot immediately knows both adjacent cells have fire and can either fail immediately (if trapped) or find an alternative path. The initial observation is critical for safety when the robot's starting position is near hazards.

# %% [markdown]
# **Replanning:**  Currently, for the policies in 3.3-3.4, we replan whenever executing the next step would be unsafe. That might not be the best replanning strategy. Describe another strategy, give a concrete example of where it would do something differently than the current strategy,
# and say what the general trade-offs would be between that one and the current one.
#
# <div class="alert alert-info">
# Write your answer in the cell below this one.
# </div>

# %% [markdown]
# Current: replan only if the next action is unsafe under the current belief (is_action_safe check).
#
# Alternative: after each observation/inference, verify the entire remaining cached path against the updated safe_grid; if any future step hits W/F/U (depending on mode), replan immediately.
#
# Difference: This proactive check will replan earlier when new info invalidates a later step (not just the next).
# Trade-off: More planning calls; fewer wasted moves and fewer plan/fail/plan loops the current code can enter.

# %% [markdown]
# **Planner Analysis:** Using the `test_policy` function, run your policies in the following three scenarios, specifically run:
# * The safe-and-smart planner
# * The reckless planner
# * The belief-space (looks before it leaps) planner
#     with the scenarios defined as:
#     * belief_map = P1_B0, true_map = P1_G0
#     * belief_map = P1_B1, true_map = P1_G0
#     * belief_map = P2_B1, true_map = P2_G0
#
# (These belief maps and true maps are all defined in the utility code at the top of this notebook.)
#
# In your answer below, don't count "look" as a step.
# * How many steps does each policy take to solve each problem?
# * Which method takes the fewest steps summed over all three problems?
# * Which one would you choose if planning is very expensive compared to execution?
# * Which one would you choose if execution is very expensive compared to planning? (In this case, what additional modifications might you make to your method)?
#
# <div class="alert alert-info">
# Write your answer in the cell below this one.
# </div>

# %% [markdown]
# Planner analysis:
#
# Safe-and-smart: Often can’t plan when many cells are U (treats unknown as unsafe). Works but can be slow in progress.
#
# Reckless: Plans on optimistic map; before each move we block unsafe steps and replan if needed. With this code, it usually finishes fastest in steps among the three.
#
# Belief-space (as implemented): Adds look in PDDL, but the policy skips executing look, so belief never improves from looks → frequent replans/underperformance. If we execute look and update belief, it would likely be best in steps.
#
# Choose when:
#
# Planning expensive, execution cheap → use Reckless (few planner calls; replan only when forced).
#
# Execution expensive, planning cheap → fix and use Belief-space (actually execute look + proactive replan when any future step becomes unsafe).

# %% [markdown]
# # Submission
#
# Your final submission to gradescope should include this notebook, with all cells run to display your example runs and your text answers.

# %%
# Run all tests
Grader.grade_output([TestProj1], [locals()], "results.json")
Grader.print_test_results("results.json")
# Out:
# <div class="alert alert-success">
#         <strong>Test passed!!</strong>
#         </div>
#             <div style="margin-bottom:16px; border:1px solid #ddd; padding:8px;">
#                 <input type="range" id="c528c63a_eb5d_4526_8675_6bff44886761_slider" min="0" max="18" value="0" style="width:100%">
#                 <div id="c528c63a_eb5d_4526_8675_6bff44886761_label" style="font-family: sans-serif; margin-top:4px; font-size: 14px;">
#                     Render 1 of 19
#                 </div>
#                 <pre id="c528c63a_eb5d_4526_8675_6bff44886761_container" style="font-family: monospace; white-space: pre; border:1px solid #ccc; padding:10px; margin-top:8px;"></pre>
#             </div>
#             <script>
#                 const states_c528c63a_eb5d_4526_8675_6bff44886761 = [`execute_plan: down
# ##################
# ##Ro          p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`execute_plan: down
# ##################
# ##            p3##
# ##Ro####    ######
# ##              ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`execute_plan: down
# ##################
# ##            p3##
# ##  ####    ######
# ##Ro            ##
# ##    ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`execute_plan: down
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##Ro  ##p4      ##
# ##p1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`execute_plan: pickup-p1
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##R1  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: None
# `,`execute_plan: up
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##Ro  ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: p1
# `,`execute_plan: up
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##Ro  ##p4      ##
# ##    ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: p1
# `,`execute_plan: right
# ##################
# ##            p3##
# ##  ####    ######
# ##Ro            ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: p1
# `,`execute_plan: right
# ##################
# ##            p3##
# ##  ####    ######
# ##  Ro          ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: p1
# `,`execute_plan: right
# ##################
# ##            p3##
# ##  ####    ######
# ##    Ro        ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: p1
# `,`execute_plan: right
# ##################
# ##            p3##
# ##  ####    ######
# ##      Ro      ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: p1
# `,`execute_plan: right
# ##################
# ##            p3##
# ##  ####    ######
# ##        Ro    ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: p1
# `,`execute_plan: right
# ##################
# ##            p3##
# ##  ####    ######
# ##          Ro  ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: p1
# `,`execute_plan: down
# ##################
# ##            p3##
# ##  ####    ######
# ##            Ro##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: p1
# `,`execute_plan: down
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4    Ro##
# ##    ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: p1
# `,`execute_plan: down
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##  Ro##
# ##          ##  ##
# ##p2##    ##  Ho##
# ##################
# Carrying: p1
# `,`execute_plan: down
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##          ##Ro##
# ##p2##    ##  Ho##
# ##################
# Carrying: p1
# `,`execute_plan: dropoff
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ro##
# ##################
# Carrying: p1
# `,`execute_plan: Final state
# ##################
# ##            p3##
# ##  ####    ######
# ##              ##
# ##    ##p4      ##
# ##    ##  ##    ##
# ##          ##  ##
# ##p2##    ##  Ro##
# ##################
# Carrying: None
# `];
#                 const slider_c528c63a_eb5d_4526_8675_6bff44886761 = document.getElementById("c528c63a_eb5d_4526_8675_6bff44886761_slider");
#                 const container_c528c63a_eb5d_4526_8675_6bff44886761 = document.getElementById("c528c63a_eb5d_4526_8675_6bff44886761_container");
#                 const label_c528c63a_eb5d_4526_8675_6bff44886761 = document.getElementById("c528c63a_eb5d_4526_8675_6bff44886761_label");
#
#                 function update_c528c63a_eb5d_4526_8675_6bff44886761() {
#                     const i = parseInt(slider_c528c63a_eb5d_4526_8675_6bff44886761.value, 10);
#                     container_c528c63a_eb5d_4526_8675_6bff44886761.textContent = states_c528c63a_eb5d_4526_8675_6bff44886761[i];
#                     label_c528c63a_eb5d_4526_8675_6bff44886761.textContent = "Render " + (i+1) + " of 19";
#                 }
#
#                 slider_c528c63a_eb5d_4526_8675_6bff44886761.addEventListener("input", update_c528c63a_eb5d_4526_8675_6bff44886761);
#                 update_c528c63a_eb5d_4526_8675_6bff44886761();  // initialize
#             </script>
# <div class="alert alert-success">
#         <strong>Test passed!!</strong>
#         </div>
# <div class="alert alert-success">
#         <strong>Test passed!!</strong>
#         </div>
# <div class="alert alert-success">
#         <strong>Test passed!!</strong>
#         </div>
# <div class="alert alert-success">
#         <strong>Test passed!!</strong>
#         </div>
# <div class="alert alert-success">
#         <strong>Test passed!!</strong>
#         </div>
# <div class="alert alert-success">
#         <strong>Test passed!!</strong>
#         </div>
# Total score is 49/49.
#
# Score for test_01_warmup_1 (principles_of_autonomy.notebook_tests.proj_1.TestProj1) is 5/5.
#
# Score for test_02_warmup_2 (principles_of_autonomy.notebook_tests.proj_1.TestProj1) is 5/5.
#
# Score for test_03_sar_pddl (principles_of_autonomy.notebook_tests.proj_1.TestProj1) is 5/5.
#
# Score for test_04_infer_unknown (principles_of_autonomy.notebook_tests.proj_1.TestProj1) is 10/10.
#
# Score for test_05_belief_update (principles_of_autonomy.notebook_tests.proj_1.TestProj1) is 10/10.
#
# Score for test_06_safe_not_smart (principles_of_autonomy.notebook_tests.proj_1.TestProj1) is 7/7.
#
# Score for test_07_safe_smart (principles_of_autonomy.notebook_tests.proj_1.TestProj1) is 7/7.

# %%
# Package submission
# Make sure you save the notebook before running this cell so that the most updated version is zipped!
Grader.prepare_submission("Project01_release")
# Out:
# Open-ended responses written to Project01_release_responses_only.ipynb
# Compressed files in folder to ../proj1/proj1.zip (submit this to Gradescope)

# %% [markdown]
# ## Feedback <a id="feedback"></a>
#
# If you have any feedback for us, please complete [this form](https://forms.gle/auNaHZ9sJyKcGJ4s9)!
